# %%
import csv
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn import linear_model
from sklearn.cross_validation import KFold
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
import numpy as np

# %%
with open("I.csv", 'rb') as csvfile:
    reader = csv.DictReader(csvfile)
    features = []
    labels = []
    for row in reader:
        feature = []
        feature.append(float(row['name']))
        feature.append(float(row['addr']))
        feature.append(float(row['post']))
        feature.append(float(row['phone']))
        features.append(feature)
        labels.append(int(row['label']))

# %%
X = np.array(features)
y = np.array(labels)

rf_clf = RandomForestClassifier(n_estimators=10, max_depth=3)
rf_clf = rf_clf.fit(X, y)

# %%
with open("J.csv", 'rb') as csvfile:
    reader = csv.DictReader(csvfile)
    t_features = []
    t_labels = []
    for row in reader:
        feature = []
        feature.append(float(row['name']))
        feature.append(float(row['addr']))
        feature.append(float(row['post']))
        feature.append(float(row['phone']))
        t_features.append(feature)
        t_labels.append(int(row['label']))

# %%
X_t = np.array(t_features)
y_t = np.array(t_labels)

y_predict = rf_clf.predict(X_t)
print (precision_score(y_t, y_predict), recall_score(y_t, y_predict), f1_score(y_t, y_predict))
# Out:
# (1.0, 0.9887640449438202, 0.99435028248587565)

# %%
with open("data_features.csv", 'rb') as csvfile:
    reader = csv.DictReader(csvfile)
    s_features = []
    for row in reader:
        feature = []
        feature.append(float(row['name']))
        feature.append(float(row['addr']))
        feature.append(float(row['post']))
        feature.append(float(row['phone']))
        s_features.append(feature)

# %%
X_s = np.array(s_features)

y_predict = rf_clf.predict(X_s)

# %%
y_predict
# Out:
# array([-1,  1, -1, ..., -1, -1,  1])

# %%
i = -1
id_pairs = []
with open("candidate_set.csv", 'rb') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        i += 1
        if y_predict[i] == -1:
            continue
            
        id_pairs.append((int(row["ltable_ID"]) - 1, int(row["rtable_ID"]) - 1))

# %%
yelp = []
advisor = []
cols = ["shop name", "postal code", "phone number", "street address", "star", "price", "number of reviews"]
with open("advisor_clean.csv", 'rb') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        advisor.append(row)
with open("yelp_clean.csv", 'rb') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        yelp.append(row)

# %%
data = []
i = 0
for l_id, r_id in id_pairs:
    data.append((i, yelp[r_id][cols[0]], yelp[r_id][cols[1]], \
                 yelp[r_id][cols[2]], yelp[r_id][cols[3]], \
                 yelp[r_id][cols[5]], yelp[r_id][cols[6]], advisor[l_id][cols[4]], \
                 advisor[l_id][cols[5]], advisor[l_id][cols[6]]))
    i += 1

# %%
data
# Out:
# [(0,
#   'sushi gen',
#   '90012',
#   '2136170552',
#   '422 e 2nd st',
#   '-1',
#   '$$$',
#   '3101',
#   '4.5',
#   '$$ - $$$',
#   '271'),
#  (1,
#   'sugarfish by sushi nozawa',
#   '90017',
#   '2136273000',
#   '600 w 7th st',
#   '-1',
#   '$$$',
#   '1776',
#   '4.5',
#   '$$ - $$$',
#   '280'),
#  (2,
#   'rocksugar pan asian kitchen',
#   '90067',
#   '3105529988',
#   '10250 santa monica blvd',
#   '-1',
#   '$$',
#   '1725',
#   '4.5',
#   '$$ - $$$',
#   '336'),
#  (3,
#   'katsuya hollywood',
#   '90028',
#   '3233912757',
#   '6300 hollywood blvd',
#   '-1',
#   '$$$',
#   '1535',
#   '4.5',
#   '$$$$',
#   '400'),
#  (4,
#   'pagoda bar at yamashiro hollywood',
#   '90068',
#   '3234665125',
#   '1999 n sycamore ave',
#   '-1',
#   '$$$',
#   '14',
#   '4.0',
#   '$$$$',
#   '618'),
#  (5,
#   'ayara thai cuisine',
#   '90045',
#   '3104108848',
#   '6245 w 87th st',
#   '-1',
#   '$$',
#   '1512',
#   '4.5',
#   '$$ - $$$',
#   '173'),
#  (6,
#   'yang chow',
#   '90012',
#   '2136250811',
#   '819 n broadway',
#   '-1',
#   '$$',
#   '1554',
#   '4.0',
#   '$$ - $$$',
#   '239'),
#  (7,
#   'n/naka',
#   '90034',
#   '3108366252',
#   '3455 overland ave',
#   '-1',
#   '$$$$',
#   '397',
#   '5.0',
#   '$$$$',
#   '77'),
#  (8,
#   'daikokuya',
#   '90064',
#   '3105754999',
#   '2208 sawtelle blvd',
#   '-1',
#   '$$',
#   '947',
#   '4.5',
#   '$',
#   '202'),
#  (9,
#   'tatsu ramen',
#   '90025',
#   '3106842889',
#   '2123 sawtelle blvd',
#   '-1',
#   '$$',
#   '1827',
#   '4.5',
#   '$$ - $$$',
#   '88'),
#  (10,
#   'genwa korean bbq',
#   '90036',
#   '3235490760',
#   '5115 wilshire blvd',
#   '-1',
#   '$$',
#   '2251',
#   '4.5',
#   '$$ - $$$',
#   '134'),
#  (11,
#   'katsuya l.a. live',
#   '90015',
#   '2138058763',
#   '800 w olympic blvd',
#   '-1',
#   '$$$',
#   '912',
#   '4.0',
#   '$$ - $$$',
#   '199'),
#  (12,
#   'komodo',
#   '90035',
#   '3102465153',
#   '8809 w pico blvd',
#   '-1',
#   '$$',
#   '1258',
#   '4.5',
#   '$',
#   '55'),
#  (13,
#   'hae jang chon korean bbq restaurant',
#   '90020',
#   '2133898777',
#   '3821 w 6th st',
#   '-1',
#   '$$',
#   '3300',
#   '4.5',
#   '$$ - $$$',
#   '50'),
#  (14,
#   'hinoki & the bird',
#   '90067',
#   '3105521200',
#   '10 w century dr',
#   '-1',
#   '$$$$',
#   '914',
#   '4.0',
#   '$$$$',
#   '147'),
#  (15,
#   'chosun galbee',
#   '90019',
#   '3237343330',
#   '3330 w olympic blvd',
#   '-1',
#   '$$$',
#   '1350',
#   '4.0',
#   '$$ - $$$',
#   '108'),
#  (16,
#   'jitlada',
#   '90027',
#   '3236679809',
#   '5233 w sunset blvd',
#   '-1',
#   '$$',
#   '1529',
#   '4.0',
#   '$$ - $$$',
#   '109'),
#  (17,
#   'bcd tofu house',
#   '90010',
#   '2133826677',
#   '3575 wilshire blvd',
#   '-1',
#   '$$',
#   '2396',
#   '4.0',
#   '$$ - $$$',
#   '129'),
#  (18,
#   'si laa',
#   '90035',
#   '3108587738',
#   '1128 s robertson blvd',
#   '-1',
#   '$$',
#   '195',
#   '5.0',
#   '$$ - $$$',
#   '48'),
#  (19,
#   'chaya downtown',
#   '90071',
#   '2132369577',
#   '525 s flower st',
#   '-1',
#   '$$$',
#   '822',
#   '4.5',
#   '$$ - $$$',
#   '102'),
#  (20,
#   'kang ho dong baekjeong',
#   '90020',
#   '2133849678',
#   '3465 w 6th st',
#   '-1',
#   '$$',
#   '2748',
#   '4.5',
#   '$$ - $$$',
#   '73'),
#  (21,
#   'wokcano',
#   '90017',
#   '2136232288',
#   '800 w 7th st',
#   '-1',
#   '$$',
#   '1112',
#   '4.0',
#   '$$ - $$$',
#   '109'),
#  (22,
#   'marugame monzo',
#   '90012',
#   '2133469762',
#   '329 e 1st st',
#   '-1',
#   '$$',
#   '1935',
#   '4.5',
#   '$$ - $$$',
#   '40'),
#  (23,
#   'pine & crane',
#   '90026',
#   '3236681128',
#   '1521 griffith park blvd',
#   '-1',
#   '$$',
#   '1112',
#   '4.5',
#   '$$ - $$$',
#   '41'),
#  (24,
#   'soowon galbi kbbq restaurant',
#   '90005',
#   '2133659292',
#   '856 s vermont ave',
#   '-1',
#   '$$',
#   '2054',
#   '4.5',
#   '$$ - $$$',
#   '53'),
#  (25,
#   'little sister',
#   '90017',
#   '2136283146',
#   '523 w 7th st',
#   '-1',
#   '$$',
#   '480',
#   '4.5',
#   '$$ - $$$',
#   '31'),
#  (26,
#   'luv2eat thai bistro',
#   '90028',
#   '3234985835',
#   '6660 w sunset blvd',
#   '-1',
#   '$$',
#   '331',
#   '4.5',
#   '$',
#   '38'),
#  (27,
#   'pink pepper',
#   '90028',
#   '3234612462',
#   '1638 north la brea avenue',
#   '-1',
#   '$$',
#   '433',
#   '4.5',
#   '$$ - $$$',
#   '65'),
#  (28,
#   'shin-sen-gumi hakata ramen - little tokyo',
#   '90012',
#   '2136877108',
#   '132 s central ave',
#   '-1',
#   '$$',
#   '1873',
#   '4.5',
#   '$$ - $$$',
#   '42'),
#  (29,
#   'triple 8 china bar & grill',
#   '90015',
#   '2137473700',
#   '800 w olympic blvd',
#   '-1',
#   '$$',
#   '278',
#   '4.0',
#   '$$ - $$$',
#   '59'),
#  (30,
#   'thai patio',
#   '90027',
#   '3234663894',
#   '5273 hollywood blvd',
#   '-1',
#   '$',
#   '1126',
#   '4.0',
#   '$',
#   '82'),
#  (31,
#   'the izaka-ya by katsu-ya',
#   '90048',
#   '3237829536',
#   '8420 w 3rd st',
#   '-1',
#   '$$$',
#   '822',
#   '4.5',
#   '$$ - $$$',
#   '97'),
#  (32,
#   'kogi bbq truck',
#   '91604',
#   '',
#   'valleyheart dr at lankershim blvd',
#   '-1',
#   '$',
#   '7',
#   '4.5',
#   '$',
#   '80'),
#  (33,
#   'kogi bbq truck - azul',
#   '',
#   '3233150253',
#   '',
#   '-1',
#   '$',
#   '2117',
#   '4.5',
#   '$',
#   '80'),
#  (34,
#   'silverlake ramen',
#   '90026',
#   '3236608100',
#   '2927 w sunset blvd',
#   '-1',
#   '$$',
#   '1836',
#   '4.5',
#   '$',
#   '36'),
#  (35,
#   'pa ord noodle',
#   '90027',
#   '3234613945',
#   '5301 sunset blvd',
#   '-1',
#   '$',
#   '1057',
#   '4.5',
#   '$',
#   '43'),
#  (36,
#   'pot',
#   '90010',
#   '2133683030',
#   '3515 wilshire blvd',
#   '-1',
#   '$$',
#   '592',
#   '4.0',
#   '$$ - $$$',
#   '106'),
#  (37,
#   'commissary',
#   '90010',
#   '2133683030',
#   '3515 wilshire blvd',
#   '-1',
#   '$$',
#   '821',
#   '4.0',
#   '$$ - $$$',
#   '106'),
#  (38,
#   'pot cafe',
#   '90010',
#   '2133683030',
#   '3515 wilshire blvd',
#   '-1',
#   '$',
#   '78',
#   '4.0',
#   '$$ - $$$',
#   '106'),
#  (39,
#   'toi on sunset',
#   '90046',
#   '3238748062',
#   '7505 1/2 w sunset blvd',
#   '-1',
#   '$$',
#   '1009',
#   '4.0',
#   '$$ - $$$',
#   '109'),
#  (40,
#   'tsujita la artisan noodle',
#   '90025',
#   '3102317373',
#   '2057 sawtelle blvd',
#   '-1',
#   '$$',
#   '2500',
#   '4.0',
#   '$$ - $$$',
#   '103'),
#  (41,
#   'tsujita la artisan noodle annex',
#   '90025',
#   '3102310222',
#   '2050 sawtelle blvd',
#   '-1',
#   '$$',
#   '1064',
#   '4.0',
#   '$$ - $$$',
#   '103'),
#  (42,
#   'quarters korean bbq',
#   '90020',
#   '2133658111',
#   '3465 w 6th st',
#   '-1',
#   '$$',
#   '1174',
#   '4.0',
#   '$$ - $$$',
#   '36'),
#  (43,
#   'shintaro japanese restaurant',
#   '90068',
#   '3238826524',
#   '1900 n highland ave',
#   '-1',
#   '$$',
#   '389',
#   '4.0',
#   '$$ - $$$',
#   '70'),
#  (44,
#   'vegan house',
#   '90028',
#   '3239626195',
#   '1717 wilcox ave',
#   '-1',
#   '$',
#   '302',
#   '4.5',
#   '$',
#   '33'),
#  (45,
#   'kanpai japanese sushi bar & grill',
#   '90045',
#   '3103387223',
#   '8325 lincoln blvd',
#   '-1',
#   '$$$',
#   '1125',
#   '4.5',
#   '$$ - $$$',
#   '88'),
#  (46,
#   'au lac',
#   '90012',
#   '2136172533',
#   '710 w 1st st',
#   '-1',
#   '$$',
#   '367',
#   '4.5',
#   '$$ - $$$',
#   '34'),
#  (47,
#   'kino sushi',
#   '90028',
#   '3234654567',
#   '6721 hollywood blvd',
#   '-1',
#   '$$',
#   '293',
#   '4.0',
#   '$$ - $$$',
#   '69'),
#  (48,
#   'the district by hannah an',
#   '90048',
#   '3102782345',
#   '8722 w 3rd st',
#   '-1',
#   '$$$',
#   '425',
#   '4.0',
#   '$$ - $$$',
#   '44'),
#  (49,
#   'sugarfish by sushi nozawa',
#   '90049',
#   '3108204477',
#   '11640 san vicente blvd',
#   '-1',
#   '$$$',
#   '873',
#   '4.5',
#   '$$ - $$$',
#   '53'),
#  (50,
#   'cho oishi',
#   '90028',
#   '3234640500',
#   '6801 hollywood blvd',
#   '-1',
#   '$$',
#   '186',
#   '3.5',
#   '$$ - $$$',
#   '130'),
#  (51,
#   'bulan thai vegetarian kitchen',
#   '90046',
#   '3238571882',
#   '7168 melrose ave',
#   '-1',
#   '$$',
#   '540',
#   '4.5',
#   '$$ - $$$',
#   '40'),
#  (52,
#   'road to seoul',
#   '90006',
#   '3237319292',
#   '1230 s western ave',
#   '-1',
#   '$$',
#   '3004',
#   '4.5',
#   '$$ - $$$',
#   '56'),
#  (53,
#   'kula revolving sushi bar',
#   '90012',
#   '2132909631',
#   '333 e 2nd st',
#   '-1',
#   '$',
#   '771',
#   '4.0',
#   '$$ - $$$',
#   '49'),
#  (54,
#   'hoy-ka thai noodles',
#   '90028',
#   '3236883558',
#   '5908 sunset blvd',
#   '-1',
#   '$',
#   '804',
#   '4.5',
#   '$',
#   '22'),
#  (55,
#   'robata jinya',
#   '90048',
#   '3236538877',
#   '8050 west 3rd st',
#   '-1',
#   '$$',
#   '805',
#   '4.5',
#   '$$ - $$$',
#   '35'),
#  (56,
#   "araya's place - thai vegan restaurant",
#   '90048',
#   '3239000557',
#   '8101 beverly blvd',
#   '-1',
#   '$$',
#   '391',
#   '5.0',
#   '$$ - $$$',
#   '15'),
#  (57,
#   'oo-kook korean bbq',
#   '90005',
#   '2133855665',
#   '3385 w 8th st',
#   '-1',
#   '$$',
#   '1119',
#   '4.0',
#   '$$ - $$$',
#   '30'),
#  (58,
#   "palm's thai restaurant",
#   '90028',
#   '3234625073',
#   '5900 hollywood blvd',
#   '-1',
#   '$$',
#   '2093',
#   '4.0',
#   '$$ - $$$',
#   '170'),
#  (59,
#   'pailin thai cuisine',
#   '90028',
#   '3234676775',
#   '5621 hollywood blvd',
#   '-1',
#   '$',
#   '263',
#   '4.5',
#   '$',
#   '22'),
#  (60,
#   'roc sawtelle',
#   '90025',
#   '3102352089',
#   '2049 sawtelle blvd',
#   '-1',
#   '$$',
#   '1346',
#   '4.0',
#   '$$ - $$$',
#   '36'),
#  (61,
#   'ekkamai thai restaurant',
#   '90066',
#   '3108272777',
#   '13223 w washington blvd',
#   '-1',
#   '$$',
#   '682',
#   '4.0',
#   '$$ - $$$',
#   '26'),
#  (62,
#   'hide sushi japanese restaurant',
#   '90025',
#   '3104777242',
#   '2040 sawtelle blvd',
#   '-1',
#   '$$',
#   '1361',
#   '4.0',
#   '$$ - $$$',
#   '82'),
#  (63,
#   'orochon ramen',
#   '90012',
#   '2136171766',
#   '123 astronaut e s onizuka st',
#   '-1',
#   '$',
#   '2734',
#   '4.0',
#   '$',
#   '75'),
#  (64,
#   "park's bbq",
#   '90006',
#   '2133801717',
#   '955 s vermont ave',
#   '-1',
#   '$$$',
#   '1244',
#   '4.5',
#   '$$ - $$$',
#   '51'),
#  (65,
#   'hollywood thai',
#   '90027',
#   '3234670926',
#   '5241 hollywood blvd',
#   '-1',
#   '$$',
#   '312',
#   '4.5',
#   '$$ - $$$',
#   '24'),
#  (66,
#   'night + market song',
#   '90026',
#   '3236655899',
#   '3322 w sunset blvd',
#   '-1',
#   '$$',
#   '422',
#   '4.5',
#   '$$ - $$$',
#   '24'),
#  (67,
#   'kabuki japanese restaurant',
#   '90045',
#   '3106415524',
#   '6081 center dr',
#   '-1',
#   '$$',
#   '606',
#   '4.0',
#   '$$ - $$$',
#   '57'),
#  (68,
#   'kazunori',
#   '90013',
#   '2134936956',
#   '421 s main st',
#   '-1',
#   '$$',
#   '1384',
#   '4.5',
#   '$$ - $$$',
#   '22'),
#  (69,
#   'bao dim sum house',
#   '90048',
#   '3236556556',
#   '8256 beverly blvd',
#   '-1',
#   '$$',
#   '1719',
#   '4.0',
#   '$$ - $$$',
#   '84'),
#  (70,
#   'sushi enya',
#   '90012',
#   '2136263692',
#   '343 e 1st st',
#   '-1',
#   '$$',
#   '820',
#   '4.5',
#   '$$ - $$$',
#   '16'),
#  (71,
#   'shabu shabu house',
#   '90012',
#   '2136803890',
#   '127 japanese village plaza mall',
#   '-1',
#   '$$',
#   '1283',
#   '4.5',
#   '$$ - $$$',
#   '67'),
#  (72,
#   'hurry curry of tokyo',
#   '90025',
#   '3104731640',
#   '2131 sawtelle blvd',
#   '-1',
#   '$$',
#   '1305',
#   '4.0',
#   '$',
#   '48'),
#  (73,
#   'blossom restaurant',
#   '90013',
#   '2136231973',
#   '426 s main st',
#   '-1',
#   '$$',
#   '995',
#   '4.0',
#   '$$ - $$$',
#   '44'),
#  (74,
#   'ruen pair',
#   '90027',
#   '3234660153',
#   '5257 hollywood blvd',
#   '-1',
#   '$',
#   '1226',
#   '4.0',
#   '$$ - $$$',
#   '29'),
#  (75,
#   "singapore's banana leaf",
#   '90036',
#   '3239334627',
#   '6333 w 3rd st',
#   '-1',
#   '$',
#   '565',
#   '4.0',
#   '$',
#   '75'),
#  (76,
#   'la rose cafe',
#   '90029',
#   '3236624024',
#   '4749 fountain ave',
#   '-1',
#   '$$',
#   '664',
#   '4.5',
#   '',
#   '28'),
#  (77,
#   'golden dragon restaurant',
#   '90012',
#   '2136262039',
#   '960 n broadway',
#   '-1',
#   '$$',
#   '451',
#   '4.0',
#   '$$ - $$$',
#   '51'),
#  (78,
#   'beverly soon tofu restaurant',
#   '90006',
#   '2133801113',
#   '2717 w olympic blvd',
#   '-1',
#   '$$',
#   '1070',
#   '4.5',
#   '$$ - $$$',
#   '29'),
#  (79,
#   'sanamluang cafe',
#   '90027',
#   '3236608006',
#   '5176 hollywood blvd',
#   '-1',
#   '$',
#   '1111',
#   '4.0',
#   '$',
#   '68'),
#  (80,
#   'ham ji park',
#   '90019',
#   '3237338333',
#   '4135 w pico blvd',
#   '-1',
#   '$$',
#   '115',
#   '4.5',
#   '$$ - $$$',
#   '15'),
#  (81,
#   "hoy's wok",
#   '90046',
#   '3238506637',
#   '7105 w sunset blvd',
#   '-1',
#   '$',
#   '262',
#   '4.0',
#   '$',
#   '25'),
#  (82,
#   'bugis street brasserie',
#   '90013',
#   '2136241100',
#   '501 s olive st',
#   '-1',
#   '$$',
#   '82',
#   '4.0',
#   '$$ - $$$',
#   '50'),
#  (83,
#   'sushi zo',
#   '90034',
#   '4242015576',
#   '9824 national blvd',
#   '-1',
#   '$$$$',
#   '686',
#   '4.5',
#   '$$$$',
#   '39'),
#  (84,
#   'seoul house of tofu',
#   '90025',
#   '3104449988',
#   '2101 sawtelle blvd',
#   '-1',
#   '$$',
#   '587',
#   '4.0',
#   '$$ - $$$',
#   '21'),
#  (85,
#   'phoenix inn chinese cuisine',
#   '90012',
#   '2136292812',
#   '301 ord st',
#   '-1',
#   '$$',
#   '291',
#   '4.5',
#   '',
#   '16'),
#  (86,
#   'soot bull jeep',
#   '90005',
#   '2133873865',
#   '3136 w 8th st',
#   '-1',
#   '$$',
#   '772',
#   '4.5',
#   '$$ - $$$',
#   '45'),
#  (87,
#   'maruya',
#   '90012',
#   '2136139988',
#   '104 japanese village plaza mall',
#   '-1',
#   '$$',
#   '423',
#   '4.0',
#   '$$ - $$$',
#   '21'),
#  (88,
#   'ahgassi gopchang',
#   '90005',
#   '2132499678',
#   '3744 w 6th st',
#   '-1',
#   '$$',
#   '769',
#   '4.5',
#   '$$ - $$$',
#   '12'),
#  (89,
#   'soi 7',
#   '90014',
#   '2135370333',
#   '518 w 7th st',
#   '-1',
#   '$$',
#   '635',
#   '4.0',
#   '$$ - $$$',
#   '40'),
#  (90,
#   'chinese friends restaurant',
#   '90012',
#   '2136261837',
#   '984 n broadway',
#   '-1',
#   '$$',
#   '239',
#   '4.5',
#   '$',
#   '18'),
#  (91,
#   'curry house',
#   '90012',
#   '2136200855',
#   '123 s onizuka st',
#   '-1',
#   '$$',
#   '991',
#   '4.0',
#   '$',
#   '47'),
#  (92,
#   "tara's himalayan cuisine",
#   '90034',
#   '3108369696',
#   '10855 venice blvd',
#   '-1',
#   '$$',
#   '914',
#   '4.0',
#   '$$ - $$$',
#   '41'),
#  (93,
#   'urban ramen',
#   '90046',
#   '3235126077',
#   '7300 w sunset blvd',
#   '-1',
#   '$$',
#   '521',
#   '4.0',
#   '$',
#   '29'),
#  (94,
#   'noshi sushi',
#   '90004',
#   '3234693458',
#   '4430 beverly blvd',
#   '-1',
#   '$$',
#   '1035',
#   '4.0',
#   '$$ - $$$',
#   '23'),
#  (95,
#   'shu sushi house unico',
#   '90077',
#   '3104742740',
#   '2932 1/2 beverly glen circle',
#   '-1',
#   '$$$',
#   '113',
#   '4.5',
#   '$$ - $$$',
#   '18'),
#  (96,
#   'furaibo restaurant',
#   '90025',
#   '3104441432',
#   '2068 sawtelle blvd',
#   '-1',
#   '$$',
#   '988',
#   '4.0',
#   '$$ - $$$',
#   '51'),
#  (97,
#   'sushi go 55',
#   '90013',
#   '2136870777',
#   '333 s alameda st',
#   '-1',
#   '$$',
#   '849',
#   '4.5',
#   '$$ - $$$',
#   '24'),
#  (98,
#   "it's pho",
#   '90028',
#   '3233807998',
#   '1821 n cahuenga blvd',
#   '-1',
#   '$$',
#   '455',
#   '4.5',
#   '',
#   '15'),
#  (99,
#   'gyu-kaku japanese bbq',
#   '90064',
#   '3102348641',
#   '10925 w pico blvd',
#   '-1',
#   '$$',
#   '842',
#   '4.0',
#   '$$ - $$$',
#   '49'),
#  (100,
#   'seoul garden restaurant',
#   '90006',
#   '2133868477',
#   '1833 w olympic blvd',
#   '-1',
#   '$$',
#   '426',
#   '4.0',
#   '$$ - $$$',
#   '29'),
#  (101,
#   'suehiro cafe',
#   '90012',
#   '2136269132',
#   '337 e 1st st',
#   '-1',
#   '$$',
#   '1045',
#   '4.0',
#   '$',
#   '34'),
#  (102,
#   'trio house',
#   '90007',
#   '2137410101',
#   '3031 s figueroa st',
#   '-1',
#   '$$',
#   '312',
#   '4.0',
#   '$$ - $$$',
#   '15'),
#  (103,
#   'mizu 212',
#   '90025',
#   '3104788979',
#   '2000 sawtelle blvd',
#   '-1',
#   '$$$',
#   '486',
#   '4.5',
#   '',
#   '24'),
#  (104,
#   'far bar',
#   '90012',
#   '2136179990',
#   '347 e 1st st',
#   '-1',
#   '$$',
#   '1612',
#   '4.0',
#   '$$ - $$$',
#   '24'),
#  (105,
#   'hokkaido ramen santouka',
#   '90066',
#   '3103911101',
#   '3760 s centinela ave',
#   '-1',
#   '$',
#   '1991',
#   '4.5',
#   '$',
#   '44'),
#  (106,
#   'kobawoo house',
#   '90005',
#   '2133897300',
#   '698 s vermont ave',
#   '-1',
#   '$$',
#   '866',
#   '4.5',
#   '$$ - $$$',
#   '19'),
#  (107,
#   'daichan',
#   '91604',
#   '8189808450',
#   '11288 ventura blvd',
#   '-1',
#   '$$',
#   '705',
#   '4.5',
#   '$$ - $$$',
#   '28'),
#  (108,
#   'seoul sausage company',
#   '90025',
#   '3104777739',
#   '11313 mississippi ave',
#   '-1',
#   '$',
#   '1224',
#   '4.0',
#   '$',
#   '22'),
#  (109,
#   'sapp coffee shop',
#   '90027',
#   '3236651035',
#   '5183 hollywood blvd',
#   '-1',
#   '$',
#   '650',
#   '4.5',
#   '$',
#   '18'),
#  (110,
#   'ayce gogi',
#   '91405',
#   '8184653050',
#   '7128 van nuys blvd',
#   '-1',
#   '$$',
#   '478',
#   '4.5',
#   '$$ - $$$',
#   '7'),
#  (111,
#   'the palace seafood & dim sum',
#   '90025',
#   '3109793377',
#   '11701 wilshire blvd',
#   '-1',
#   '$$',
#   '362',
#   '4.0',
#   '$$ - $$$',
#   '25'),
#  (112,
#   'my ramen bar',
#   '90012',
#   '2136139888',
#   '321 1/4 e 1st st',
#   '-1',
#   '$$',
#   '438',
#   '4.5',
#   '$',
#   '13'),
#  (113,
#   'gobi mongolian bbq house',
#   '90026',
#   '2139890711',
#   '2827 w sunset blvd',
#   '-1',
#   '$$',
#   '583',
#   '4.5',
#   '$$ - $$$',
#   '18'),
#  (114,
#   'arashi sushi',
#   '90015',
#   '2137491900',
#   '1111 s hope st',
#   '-1',
#   '$$',
#   '576',
#   '4.5',
#   '$$ - $$$',
#   '31'),
#  (115,
#   'dong ii jang restaurant',
#   '90005',
#   '2133835757',
#   '3455 w 8th st',
#   '-1',
#   '$$',
#   '490',
#   '4.5',
#   '$$ - $$$',
#   '26'),
#  (116,
#   'shunji japanese cuisine',
#   '90064',
#   '3108264737',
#   '12244 w pico blvd',
#   '-1',
#   '$$$$',
#   '232',
#   '4.5',
#   '',
#   '16'),
#  (117,
#   'simpang asia',
#   '90034',
#   '3108159075',
#   '10433 national blvd',
#   '-1',
#   '$',
#   '974',
#   '4.5',
#   '$',
#   '30'),
#  (118,
#   'moodaepo ii',
#   '90005',
#   '2133819990',
#   '3014 w 7th st',
#   '-1',
#   '$$',
#   '1376',
#   '4.5',
#   '',
#   '12'),
#  (119,
#   'nong la cafe',
#   '90025',
#   '3102681881',
#   '2055 sawtelle blvd',
#   '-1',
#   '$$',
#   '1104',
#   '4.5',
#   '$',
#   '13'),
#  (120,
#   'melanee thai',
#   '90035',
#   '3102734066',
#   '9562 w pico blvd',
#   '-1',
#   '$$',
#   '285',
#   '4.5',
#   '$$ - $$$',
#   '21'),
#  (121,
#   'ocha classic',
#   '90005',
#   '2133834249',
#   '835 s vermont ave',
#   '-1',
#   '$$',
#   '377',
#   '4.0',
#   '$',
#   '11'),
#  (122,
#   'shanghai glatt kosher',
#   '90035',
#   '3105530998',
#   '9401 w pico blvd',
#   '-1',
#   '$$',
#   '113',
#   '4.0',
#   '$$ - $$$',
#   '19'),
#  (123,
#   'jinya ramen bar',
#   '90036',
#   '3239546477',
#   '5168 wilshire bld',
#   '-1',
#   '$$',
#   '387',
#   '4.5',
#   '',
#   '12'),
#  (124,
#   'mr noodle',
#   '90024',
#   '3102087808',
#   '936 broxton ave',
#   '-1',
#   '$',
#   '570',
#   '4.0',
#   '$',
#   '27'),
#  (125,
#   'chibiscus asian cafe',
#   '90046',
#   '3234519896',
#   '7361 w sunset blvd',
#   '-1',
#   '$$',
#   '788',
#   '4.5',
#   '',
#   '11'),
#  (126,
#   'octopus japanese restaurant',
#   '90017',
#   '2134021500',
#   '729 w. 7th street',
#   '-1',
#   '$$',
#   '1198',
#   '4.0',
#   '$$ - $$$',
#   '39'),
#  (127,
#   'sakura house',
#   '90066',
#   '3103067010',
#   '13362 w washington blvd',
#   '-1',
#   '$$',
#   '262',
#   '4.5',
#   '$$ - $$$',
#   '14'),
#  (128,
#   'baroo',
#   '90038',
#   '3238194344',
#   '5706 santa monica blvd',
#   '-1',
#   '$$',
#   '171',
#   '4.5',
#   '$$ - $$$',
#   '6'),
#  (129,
#   'pho 87',
#   '90012',
#   '3232270758',
#   '1019 n broadway',
#   '-1',
#   '$',
#   '998',
#   '4.0',
#   '$',
#   '24'),
#  (130,
#   'kiku sushi',
#   '90004',
#   '3234641323',
#   '246 n larchmont blvd',
#   '-1',
#   '$$',
#   '287',
#   '4.0',
#   '$$ - $$$',
#   '19'),
#  (131,
#   'chung ki wa',
#   '90019',
#   '3237370809',
#   '3545 w olympic blvd',
#   '-1',
#   '$$',
#   '313',
#   '4.5',
#   '$$ - $$$',
#   '12'),
#  (132,
#   'escala',
#   '90020',
#   '2133871113',
#   '3451 w 6th st',
#   '-1',
#   '$$',
#   '556',
#   '4.5',
#   '$$ - $$$',
#   '12'),
#  (133,
#   'won kok restaurant',
#   '90012',
#   '2136130700',
#   '210 alpine st',
#   '-1',
#   '$',
#   '767',
#   '4.0',
#   '$',
#   '30'),
#  (134,
#   'eight korean bbq',
#   '90005',
#   '2133651750',
#   '863 s western ave',
#   '-1',
#   '$$',
#   '1216',
#   '4.5',
#   '',
#   '5'),
#  (135,
#   'tawanna thai',
#   '90048',
#   '3239392450',
#   '6236 wilshire blvd',
#   '-1',
#   '$$',
#   '271',
#   '4.0',
#   '$',
#   '20'),
#  (136,
#   'manpuku tokyo bbq',
#   '90025',
#   '3104730580',
#   '2125 sawtelle blvd',
#   '-1',
#   '$$',
#   '482',
#   '4.5',
#   '$$ - $$$',
#   '32'),
#  (137,
#   "slurpin' ramen bar",
#   '90005',
#   '2133888607',
#   '3500 w 8th st',
#   '-1',
#   '$$',
#   '1182',
#   '4.5',
#   '',
#   '6'),
#  (138,
#   'sticky rice',
#   '90013',
#   '2136212865',
#   '317 s broadway',
#   '-1',
#   '$$',
#   '525',
#   '4.0',
#   '$',
#   '16'),
#  (139,
#   'emporium thai',
#   '90024',
#   '3104782838',
#   '1275 westwood blvd',
#   '-1',
#   '$$',
#   '1092',
#   '4.0',
#   '$$ - $$$',
#   '44'),
#  (140,
#   'red corner asia',
#   '90027',
#   '3234666722',
#   '5267 hollywood blvd',
#   '-1',
#   '$$',
#   '694',
#   '4.0',
#   '$$ - $$$',
#   '35'),
#  (141,
#   'mae ploy restaurant',
#   '90026',
#   '2133539635',
#   '2606 w sunset blvd',
#   '-1',
#   '$',
#   '377',
#   '4.5',
#   '$',
#   '15'),
#  (142,
#   'viet noodle bar atwater',
#   '90039',
#   '3239061575',
#   '3133 glendale blvd',
#   '-1',
#   '$$',
#   '452',
#   '4.0',
#   '$$ - $$$',
#   '16'),
#  (143,
#   'hamakaze sushi izakaya',
#   '90066',
#   '3108229900',
#   '13327 w washington blvd',
#   '-1',
#   '$$',
#   '345',
#   '4.5',
#   '$$ - $$$',
#   '17'),
#  (144,
#   'myung dong kyoja',
#   '90010',
#   '2133857789',
#   '3630 wilshire blvd',
#   '-1',
#   '$',
#   '930',
#   '4.0',
#   '$$ - $$$',
#   '18'),
#  (145,
#   "o'woks",
#   '90035',
#   '3102461326',
#   '8657 w pico blvd',
#   '-1',
#   '$$',
#   '57',
#   '4.5',
#   '',
#   '7'),
#  (146,
#   'peking tavern',
#   '90014',
#   '2139888308',
#   '806 s spring st',
#   '-1',
#   '$$',
#   '506',
#   '4.0',
#   '$$ - $$$',
#   '15'),
#  (147,
#   'a-won japanese restaurant',
#   '90006',
#   '2133896764',
#   '913 s vermont ave',
#   '-1',
#   '$$',
#   '211',
#   '4.0',
#   '$$ - $$$',
#   '10'),
#  (148,
#   'sakura japanese restaurant',
#   '90066',
#   '3108227790',
#   '4545 s centinela ave',
#   '-1',
#   '$$',
#   '736',
#   '4.0',
#   '$$ - $$$',
#   '37'),
#  (149,
#   'the bun shop',
#   '90004',
#   '3234681031',
#   '151 n western ave',
#   '-1',
#   '$',
#   '844',
#   '4.5',
#   '',
#   '10'),
#  (150,
#   'vegan glory',
#   '90048',
#   '3236534900',
#   '8393 beverly blvd',
#   '-1',
#   '$$',
#   '625',
#   '4.0',
#   '$',
#   '35'),
#  (151,
#   'nanbankan',
#   '90025',
#   '3104781591',
#   '11330 santa monica blvd',
#   '-1',
#   '$$',
#   '564',
#   '4.5',
#   '$$ - $$$',
#   '27'),
#  (152,
#   'mandarette chinese cafe',
#   '90048',
#   '3236556115',
#   '8386 beverly blvd',
#   '-1',
#   '$$',
#   '213',
#   '4.0',
#   '$$ - $$$',
#   '34'),
#  (153,
#   'cha cha chili',
#   '90032',
#   '3232228900',
#   '4625 valley blvd',
#   '-1',
#   '$',
#   '918',
#   '4.5',
#   '',
#   '7'),
#  (154,
#   'fresh in the box',
#   '90066',
#   '3103019100',
#   '13354 w washington blvd',
#   '-1',
#   '$$',
#   '348',
#   '5.0',
#   '$$ - $$$',
#   '12'),
#  (155,
#   'han bat sul lung tang',
#   '90020',
#   '2133839499',
#   '4163 w 5th st',
#   '-1',
#   '$',
#   '1358',
#   '4.5',
#   '$',
#   '11'),
#  (156,
#   'sushi masu',
#   '90025',
#   '3104464368',
#   '1911 westwood blvd',
#   '-1',
#   '$$$',
#   '383',
#   '4.5',
#   '$$ - $$$',
#   '21'),
#  (157,
#   'izakaya fu-ga',
#   '90012',
#   '2136251722',
#   '111 s san pedro st',
#   '-1',
#   '$$',
#   '687',
#   '4.5',
#   '$$ - $$$',
#   '17'),
#  (158,
#   'wokcano',
#   '90046',
#   '3234509037',
#   '8000 w sunset blvd',
#   '-1',
#   '$$',
#   '209',
#   '4.0',
#   '$$ - $$$',
#   '16'),
#  (159,
#   'vegan house',
#   '90026',
#   '2134832105',
#   '2703 w sunset blvd',
#   '-1',
#   '$',
#   '311',
#   '4.0',
#   '$',
#   '15'),
#  (160,
#   'hop louie',
#   '90012',
#   '2136284244',
#   '950 mei ling way',
#   '-1',
#   '$',
#   '238',
#   '4.0',
#   '$$ - $$$',
#   '18'),
#  (161,
#   'kaya street kitchen',
#   '90036',
#   '3238799288',
#   '109 n fairfax ave',
#   '-1',
#   '$',
#   '529',
#   '4.5',
#   '$',
#   '7'),
#  (162,
#   "hu's szechwan restaurant",
#   '90034',
#   '3108370252',
#   '10450 national blvd',
#   '-1',
#   '$$',
#   '293',
#   '4.5',
#   '$$ - $$$',
#   '20'),
#  (163,
#   'yuko kitchen',
#   '90036',
#   '3239334020',
#   '5484 wilshire blvd',
#   '-1',
#   '$$',
#   '1063',
#   '4.0',
#   '$',
#   '16'),
#  (164,
#   'feast from the east',
#   '90025',
#   '3104750400',
#   '1949 westwood blvd',
#   '-1',
#   '$$',
#   '391',
#   '4.0',
#   '$$ - $$$',
#   '22'),
#  (165,
#   'yabu restaurant',
#   '90064',
#   '3104739757',
#   '11820 w pico blvd',
#   '-1',
#   '$$',
#   '344',
#   '4.5',
#   '$$ - $$$',
#   '26'),
#  (166,
#   'shophouse southeast asian kitchen',
#   '90024',
#   '4244421171',
#   '1059 broxton ave',
#   '-1',
#   '$',
#   '248',
#   '4.0',
#   '$',
#   '10'),
#  (167,
#   'yai restaurant',
#   '90028',
#   '3234620292',
#   '5757 hollywood blvd',
#   '-1',
#   '$',
#   '428',
#   '4.0',
#   '$',
#   '24'),
#  (168,
#   'king buffet',
#   '90027',
#   '3234689398',
#   '1375 n western ave',
#   '-1',
#   '$$',
#   '273',
#   '4.0',
#   '$',
#   '23'),
#  (169,
#   'toshi sushi',
#   '90012',
#   '2136804166',
#   '359 e 1st st',
#   '-1',
#   '$$',
#   '332',
#   '4.5',
#   '$$ - $$$',
#   '15'),
#  (170,
#   'lemongrass',
#   '90041',
#   '3232588050',
#   '1952 colorado blvd',
#   '-1',
#   '$',
#   '113',
#   '4.5',
#   '$$ - $$$',
#   '17'),
#  (171,
#   'full house seafood restaurant',
#   '90012',
#   '2136178382',
#   '963 n hill st',
#   '-1',
#   '$$',
#   '529',
#   '4.0',
#   '$$ - $$$',
#   '25'),
#  (172,
#   'ocean seafood restaurant',
#   '90012',
#   '2136873088',
#   '750 n hill st',
#   '-1',
#   '$$',
#   '828',
#   '3.5',
#   '$$ - $$$',
#   '88'),
#  (173,
#   'kiriko',
#   '90064',
#   '3104787769',
#   '11301 w olympic blvd',
#   '-1',
#   '$$$',
#   '395',
#   '4.0',
#   '$$ - $$$',
#   '24'),
#  (174,
#   'hodori restaurant',
#   '90006',
#   '2133833554',
#   '1001 s vermont ave',
#   '-1',
#   '$$',
#   '875',
#   '4.0',
#   '$$ - $$$',
#   '23'),
#  (175,
#   'boba loca',
#   '90024',
#   '3104438911',
#   '10946 weyburn ave',
#   '-1',
#   '$',
#   '308',
#   '5.0',
#   '$',
#   '6'),
#  (176,
#   'ondal 2',
#   '90016',
#   '3239333228',
#   '4566 w washington blvd',
#   '-1',
#   '$$',
#   '375',
#   '5.0',
#   '$$ - $$$',
#   '3'),
#  (177,
#   'feng mao lamb kebab',
#   '90019',
#   '3237469644',
#   '3901 w olympic blvd',
#   '-1',
#   '$$',
#   '283',
#   '5.0',
#   '',
#   '4'),
#  (178,
#   'khun dom thai',
#   '90029',
#   '3236631086',
#   '4681 melrose ave',
#   '-1',
#   '$',
#   '107',
#   '4.5',
#   '',
#   '2'),
#  (179,
#   'hashi',
#   '90012',
#   '2136170237',
#   '442 e 2nd st',
#   '-1',
#   '$$',
#   '191',
#   '4.5',
#   '',
#   '4'),
#  (180,
#   'ob bear',
#   '90005',
#   '2134804910',
#   '3002 w 7th st',
#   '-1',
#   '$$',
#   '578',
#   '4.0',
#   '$$ - $$$',
#   '5'),
#  (181,
#   'meizhou dongpo restaurant',
#   '90067',
#   '3107880120',
#   '10250 santa monica blvd',
#   '-1',
#   '$$$',
#   '403',
#   '3.5',
#   '$$ - $$$',
#   '21'),
#  (182,
#   'mitsuru cafe',
#   '90012',
#   '2136131028',
#   '117 japanese village plz mall',
#   '-1',
#   '$',
#   '655',
#   '4.0',
#   '',
#   '22'),
#  (183,
#   'tuk tuk thai',
#   '90035',
#   '3108601872',
#   '8875 w pico blvd',
#   '-1',
#   '$$',
#   '352',
#   '4.0',
#   '$$ - $$$',
#   '20'),
#  (184,
#   'bud namu korean bbq',
#   '90005',
#   '2133859292',
#   '809 s ardmore ave',
#   '-1',
#   '$$',
#   '959',
#   '4.5',
#   '',
#   '7'),
#  (185,
#   'the prince',
#   '90005',
#   '2133891586',
#   '3198 1/2 w 7th st',
#   '-1',
#   '$$',
#   '446',
#   '4.5',
#   '',
#   '7'),
#  (186,
#   'taiko',
#   '90049',
#   '3102077782',
#   '11677 san vicente blvd',
#   '-1',
#   '$$',
#   '168',
#   '4.0',
#   '$$ - $$$',
#   '14'),
#  (187,
#   'chunju han-il kwan',
#   '90020',
#   '2134801799',
#   '3450 w 6th st',
#   '-1',
#   '$$',
#   '565',
#   '4.0',
#   '$$ - $$$',
#   '8'),
#  (188,
#   'western doma noodles',
#   '90004',
#   '3238711955',
#   '429 n western ave',
#   '-1',
#   '$',
#   '451',
#   '4.0',
#   '',
#   '10'),
#  (189,
#   'chao krung restaurant',
#   '90036',
#   '3239398361',
#   '111 n fairfax ave',
#   '-1',
#   '$$',
#   '198',
#   '4.0',
#   '$$ - $$$',
#   '17'),
#  (190,
#   'ramayani',
#   '90024',
#   '3104773315',
#   '1777 westwood blvd',
#   '-1',
#   '$$',
#   '405',
#   '4.0',
#   '$$ - $$$',
#   '24'),
#  (191,
#   'chan dara restaurant',
#   '90004',
#   '3234671052',
#   '310 n larchmont blvd',
#   '-1',
#   '$$',
#   '298',
#   '4.0',
#   '$$ - $$$',
#   '23'),
#  (192,
#   'pho cafe',
#   '90026',
#   '2134130888',
#   '2841 w sunset blvd',
#   '-1',
#   '$',
#   '1193',
#   '4.0',
#   '$',
#   '37'),
#  (193,
#   'wat dong moon lek noodle',
#   '90029',
#   '3236665993',
#   '4356 fountain ave',
#   '-1',
#   '$$',
#   '757',
#   '5.0',
#   '',
#   '5'),
#  (194,
#   'green leaves vegan',
#   '90027',
#   '3236642345',
#   '1769 hillhurst ave',
#   '-1',
#   '$',
#   '523',
#   '4.5',
#   '$',
#   '15'),
#  (195,
#   'kouraku restaurant',
#   '90012',
#   '2136874972',
#   '314 e 2nd st',
#   '-1',
#   '$',
#   '866',
#   '3.5',
#   '$',
#   '27'),
#  (196,
#   'korean kitchen hibachi barbeque',
#   '90012',
#   '2136801039',
#   '135 japanese village pl mall',
#   '-1',
#   '$$',
#   '251',
#   '4.0',
#   '$',
#   '10'),
#  (197,
#   'bibigo',
#   '90024',
#   '3108240011',
#   '1091 broxton ave',
#   '-1',
#   '$',
#   '476',
#   '4.0',
#   '$',
#   '20'),
#  (198,
#   'wasabi japanese noodle house',
#   '90010',
#   '2133410999',
#   '3444 wilshire blvd',
#   '-1',
#   '$',
#   '180',
#   '4.0',
#   '',
#   '7'),
#  (199,
#   'hop woo',
#   '90012',
#   '2136173038',
#   '845 n broadway',
#   '-1',
#   '$$',
#   '334',
#   '3.5',
#   '$$ - $$$',
#   '38'),
#  (200,
#   'three flames mongolian bar-b-q',
#   '90045',
#   '3106416868',
#   '5608 w manchester ave',
#   '-1',
#   '$$',
#   '145',
#   '4.0',
#   '$',
#   '9'),
#  (201,
#   'dan sung sa',
#   '90020',
#   '2134879100',
#   '3317 w 6th st',
#   '-1',
#   '$$',
#   '571',
#   '4.0',
#   '$$ - $$$',
#   '9'),
#  (202,
#   'gushi',
#   '90024',
#   '3102084038',
#   '978 gayley ave',
#   '-1',
#   '$',
#   '864',
#   '4.0',
#   '',
#   '16'),
#  (203,
#   'khan shabu shabu',
#   '90004',
#   '3234656688',
#   '210 n western ave',
#   '-1',
#   '$$',
#   '280',
#   '4.0',
#   '$$ - $$$',
#   '8'),
#  (204,
#   'eight korean bbq',
#   '90005',
#   '2133651750',
#   '863 s western ave',
#   '-1',
#   '$$',
#   '1216',
#   '4.5',
#   '',
#   '7'),
#  (205,
#   'galbi king',
#   '90064',
#   '3104776075',
#   '11267 national blvd',
#   '-1',
#   '$$',
#   '322',
#   '4.0',
#   '$',
#   '14'),
#  (206,
#   'tofu ya',
#   '90025',
#   '3104732627',
#   '2021 sawtelle blvd',
#   '-1',
#   '$$',
#   '962',
#   '4.0',
#   '$',
#   '20'),
#  (207,
#   'gingergrass',
#   '90039',
#   '3236441600',
#   '2396 glendale blvd',
#   '-1',
#   '$$',
#   '905',
#   '4.0',
#   '$$ - $$$',
#   '69'),
#  (208,
#   'honey pig',
#   '90005',
#   '2133800256',
#   '3400 w 8th st',
#   '-1',
#   '$$',
#   '831',
#   '4.0',
#   '$$ - $$$',
#   '26'),
#  (209,
#   'torung restaurant',
#   '90028',
#   '3234642750',
#   '5657 hollywood blvd',
#   '-1',
#   '$',
#   '385',
#   '4.0',
#   '$',
#   '21'),
#  (210,
#   'myung dong noodle house',
#   '90005',
#   '2132511066',
#   '698 irolo st',
#   '-1',
#   '$',
#   '81',
#   '4.0',
#   '',
#   '2'),
#  (211,
#   'hangari kalguksu',
#   '90020',
#   '2133882326',
#   '3470 w 6th st',
#   '-1',
#   '$$',
#   '605',
#   '4.0',
#   '',
#   '6'),
#  (212,
#   'kyochon',
#   '90020',
#   '2137399292',
#   '3833 w 6th st',
#   '-1',
#   '$$',
#   '1619',
#   '4.0',
#   '$',
#   '21'),
#  (213,
#   'first szechuan wok',
#   '90024',
#   '3102087785',
#   '10855 lindbrook dr',
#   '-1',
#   '$$',
#   '142',
#   '3.5',
#   '',
#   '15'),
#  (214,
#   'zencu sushi & grill',
#   '90012',
#   '2136877780',
#   '319 e 2nd st',
#   '-1',
#   '$$',
#   '445',
#   '3.5',
#   '$$ - $$$',
#   '15'),
#  (215,
#   'pho 2000',
#   '90004',
#   '3234615845',
#   '215 n western ave',
#   '-1',
#   '$',
#   '430',
#   '4.0',
#   '$',
#   '25'),
#  (216,
#   'bang na thai fusion',
#   '90012',
#   '3236986569',
#   '637 n spring st',
#   '-1',
#   '$$',
#   '115',
#   '4.0',
#   '$$ - $$$',
#   '4'),
#  (217,
#   'chi dynasty',
#   '90027',
#   '3236673388',
#   '1813 hillhurst ave',
#   '-1',
#   '$$',
#   '366',
#   '4.0',
#   '$$ - $$$',
#   '30'),
#  (218,
#   'wako donkasu',
#   '90006',
#   '2133879256',
#   '2904 w olympic blvd',
#   '-1',
#   '$$',
#   '444',
#   '4.0',
#   '$$ - $$$',
#   '6'),
#  (219,
#   'abc seafood restaurant',
#   '90012',
#   '2136802887',
#   '708 new high st',
#   '-1',
#   '$',
#   '231',
#   '3.5',
#   '$',
#   '17'),
#  (220,
#   'thai dishes',
#   '90045',
#   '3103420046',
#   '6234 w manchester ave',
#   '-1',
#   '$$',
#   '294',
#   '3.5',
#   '$$ - $$$',
#   '20'),
#  (221,
#   'hop woo',
#   '90064',
#   '3105753668',
#   '11110 w olympic blvd',
#   '-1',
#   '$$',
#   '275',
#   '4.0',
#   '',
#   '19'),
#  (222,
#   'o dae san korean bbq',
#   '90006',
#   '2133839800',
#   '2889 w olympic blvd',
#   '-1',
#   '$$',
#   '1217',
#   '3.5',
#   '$$ - $$$',
#   '15'),
#  (223,
#   'twin dragon chinese restaurant',
#   '90035',
#   '3106577355',
#   '8597 w pico blvd',
#   '-1',
#   '$$',
#   '363',
#   '3.5',
#   '$$ - $$$',
#   '23'),
#  (224,
#   'olympic noodle',
#   '90019',
#   '3239310007',
#   '4008 w olympic blvd',
#   '-1',
#   '$',
#   '288',
#   '4.0',
#   '',
#   '4'),
#  (225,
#   'cr\xc3\xa8me caramel la',
#   '91411',
#   '8189498352',
#   '14849 burbank blvd',
#   '-1',
#   '$$',
#   '506',
#   '4.0',
#   '$',
#   '1'),
#  (226,
#   'plato',
#   '90005',
#   '2133831984',
#   '3474 w 8th st',
#   '-1',
#   '$$',
#   '153',
#   '4.0',
#   '',
#   '1'),
#  (227,
#   'nak won house',
#   '90006',
#   '2133888889',
#   '1001 s vermont ave',
#   '-1',
#   '$$',
#   '308',
#   '3.5',
#   '',
#   '7'),
#  (228,
#   'corner place',
#   '90006',
#   '2134870968',
#   '2819 james m wood blvd',
#   '-1',
#   '$$',
#   '792',
#   '4.0',
#   '$',
#   '16'),
#  (229,
#   'shabu hyang',
#   '90010',
#   '2133845464',
#   '3807 wilshire blvd',
#   '-1',
#   '$$',
#   '236',
#   '3.5',
#   '$$ - $$$',
#   '3'),
#  (230,
#   'healthy zone jook hyang',
#   '90006',
#   '2134875002',
#   '3177 w olympic blvd',
#   '-1',
#   '$$',
#   '171',
#   '2.5',
#   '',
#   '3'),
#  (231,
#   'bamboo house',
#   '90027',
#   '3236682437',
#   '4852 hollywood blvd',
#   '-1',
#   '$$',
#   '184',
#   '4.0',
#   '',
#   '3'),
#  (232,
#   'bak kung korean bbq',
#   '90019',
#   '3237349292',
#   '3700 w olympic blvd',
#   '-1',
#   '$$',
#   '210',
#   '3.5',
#   '$$ - $$$',
#   '5'),
#  (233,
#   'gam ja gol',
#   '90006',
#   '2133816446',
#   '3003 w olympic blvd',
#   '-1',
#   '$$',
#   '275',
#   '4.0',
#   '',
#   '4'),
#  (234,
#   'haus by coffee hunter',
#   '90020',
#   '2133885311',
#   '3826 w 6th st',
#   '-1',
#   '$$',
#   '1030',
#   '3.0',
#   '$$ - $$$',
#   '9'),
#  (235,
#   'noodle world jr.',
#   '90045',
#   '3102169888',
#   '8636 s sepulveda blvd',
#   '-1',
#   '$',
#   '135',
#   '3.0',
#   '',
#   '6'),
#  (236,
#   'pho thai town',
#   '90027',
#   '3236670934',
#   '5136 hollywood blvd',
#   '-1',
#   '$',
#   '239',
#   '3.5',
#   '',
#   '2'),
#  (237,
#   'blue cow kitchen & bar',
#   '90071',
#   '2136212249',
#   '350 s grand ave',
#   '-1',
#   '$$',
#   '940',
#   '4.0',
#   '',
#   '8'),
#  (238,
#   'cafe nandarang',
#   '90020',
#   '2133888513',
#   '3815 w 6th st',
#   '-1',
#   '$$',
#   '303',
#   '3.5',
#   '',
#   '2'),
#  (239,
#   'plum tree inn',
#   '90012',
#   '2136131819',
#   '913 n broadway',
#   '-1',
#   '$$',
#   '295',
#   '4.0',
#   '$$ - $$$',
#   '42'),
#  (240,
#   'shanghai rose',
#   '91604',
#   '8187622542',
#   '12229 ventura blvd',
#   '-1',
#   '$$',
#   '169',
#   '3.0',
#   '$$ - $$$',
#   '12'),
#  (241,
#   'asahi ramen',
#   '90025',
#   '3104792231',
#   '2027 sawtelle blvd',
#   '-1',
#   '$',
#   '647',
#   '4.0',
#   '$',
#   '33'),
#  (242,
#   "fu's palace",
#   '90035',
#   '3102717887',
#   '8751 w pico blvd',
#   '-1',
#   '$$',
#   '281',
#   '3.0',
#   '$$ - $$$',
#   '13'),
#  (243,
#   'yohana sushi & asian cuisine',
#   '90064',
#   '3108376278',
#   '2536 overland ave',
#   '-1',
#   '$$',
#   '119',
#   '-1',
#   '',
#   '-1'),
#  (244,
#   'house of macau',
#   '90028',
#   '3237455038',
#   '1600 vine st',
#   '-1',
#   '$$',
#   '128',
#   '-1',
#   '',
#   '-1'),
#  (245,
#   'roasted sesame kitchen',
#   '90029',
#   '3233504641',
#   '4632 santa monica blvd',
#   '-1',
#   '$',
#   '27',
#   '-1',
#   '$$ - $$$',
#   '-1'),
#  (246,
#   'miari noodle house',
#   '90006',
#   '3237350647',
#   '3224 w olympic blvd',
#   '-1',
#   '$',
#   '76',
#   '-1',
#   '',
#   '-1'),
#  (247,
#   'zen mei bistro',
#   '90012',
#   '2136267113',
#   '800 yale st',
#   '-1',
#   '$',
#   '105',
#   '4.5',
#   '$',
#   '9'),
#  (248,
#   "uncle john's cafe",
#   '90017',
#   '2136233555',
#   '834 s grand ave',
#   '-1',
#   '$',
#   '263',
#   '4.5',
#   '$',
#   '10'),
#  (249,
#   'little china restaurant',
#   '90068',
#   '3239698838',
#   '3535 cahuenga blvd w',
#   '-1',
#   '$',
#   '139',
#   '4.5',
#   '$',
#   '9'),
#  (250,
#   "wah's golden hen",
#   '90029',
#   '3236610093',
#   '709 n virgil ave',
#   '-1',
#   '$',
#   '275',
#   '5.0',
#   '$',
#   '5'),
#  (251,
#   'moon house chinese cuisine',
#   '90025',
#   '3109669988',
#   '11058 santa monica blvd',
#   '-1',
#   '$$',
#   '286',
#   '4.5',
#   '',
#   '10'),
#  (252,
#   'china cafe at grand central market',
#   '90013',
#   '2136288481',
#   '317 s broadway',
#   '-1',
#   '$',
#   '153',
#   '4.5',
#   '',
#   '8'),
#  (253,
#   'eagle rock green dragon',
#   '90041',
#   '3232558889',
#   '1735 colorado blvd',
#   '-1',
#   '$$',
#   '307',
#   '4.5',
#   '$$ - $$$',
#   '8'),
#  (254,
#   'golden city seafood restaurant',
#   '90012',
#   '2132532660',
#   '960 n hill st',
#   '-1',
#   '$',
#   '201',
#   '4.5',
#   '$$ - $$$',
#   '9'),
#  (255,
#   'siam chan',
#   '90066',
#   '3109157408',
#   '12470 venice blvd',
#   '-1',
#   '$',
#   '174',
#   '4.0',
#   '',
#   '8'),
#  (256,
#   'liliya china bistro',
#   '90012',
#   '2136201717',
#   '108 w 2nd st',
#   '-1',
#   '$$',
#   '117',
#   '4.5',
#   '',
#   '13'),
#  (257,
#   'cheng du restaurant',
#   '90064',
#   '3104774917',
#   '11538 w pico blvd',
#   '-1',
#   '$$',
#   '221',
#   '4.0',
#   '$$ - $$$',
#   '12'),
#  (258,
#   'regent china inn',
#   '90012',
#   '2136803333',
#   '747 n main st',
#   '-1',
#   '$',
#   '217',
#   '4.0',
#   '$',
#   '11'),
#  (259,
#   'heung rae gak',
#   '90020',
#   '2133830178',
#   '357 s western ave',
#   '-1',
#   '$$',
#   '107',
#   '5.0',
#   '',
#   '2'),
#  (260,
#   'new panda buffet',
#   '90016',
#   '3232915555',
#   '5120 rodeo rd',
#   '-1',
#   '$',
#   '109',
#   '5.0',
#   '',
#   '2'),
#  (261,
#   'hunan tasty - temp. closed',
#   '90036',
#   '3239365621',
#   '6031 san vicente blvd',
#   '-1',
#   '$$',
#   '151',
#   '4.5',
#   '',
#   '10'),
#  (262,
#   'the new moon',
#   '90015',
#   '2136240186',
#   '102 w 9th st',
#   '-1',
#   '$$',
#   '204',
#   '4.5',
#   '$$ - $$$',
#   '6'),
#  (263,
#   'wok on fire',
#   '90035',
#   '3102890102',
#   '1447 s la cienega blvd',
#   '-1',
#   '$$',
#   '234',
#   '4.5',
#   '',
#   '3'),
#  (264,
#   'hunan cafe',
#   '90046',
#   '3238221208',
#   '7986 sunset blvd',
#   '-1',
#   '$$',
#   '172',
#   '4.5',
#   '$$ - $$$',
#   '10'),
#  (265,
#   'mandarin kitchen',
#   '90025',
#   '3104419651',
#   '1822 westwood blvd',
#   '-1',
#   '$',
#   '283',
#   '4.0',
#   '',
#   '6'),
#  (266,
#   'coral reef chinese restaurant',
#   '90039',
#   '3236603260',
#   '3200 glendale blvd',
#   '-1',
#   '$',
#   '106',
#   '4.5',
#   '',
#   '2'),
#  (267,
#   'chuan chim',
#   '90028',
#   '3234626221',
#   '5644 hollywood blvd',
#   '-1',
#   '$',
#   '80',
#   '4.5',
#   '',
#   '3'),
#  (268,
#   'green tea house',
#   '90046',
#   '3238746777',
#   '7226 w sunset blvd',
#   '-1',
#   '$',
#   '216',
#   '4.5',
#   '',
#   '5'),
#  (269,
#   'california wok',
#   '90025',
#   '3102072852',
#   '12004 wilshire blvd',
#   '-1',
#   '$$',
#   '196',
#   '3.5',
#   '$$ - $$$',
#   '11'),
#  (270,
#   'shin beijing',
#   '90006',
#   '2133813003',
#   '3101 w olympic blvd',
#   '-1',
#   '$$',
#   '163',
#   '4.5',
#   '',
#   '5'),
#  (271,
#   'master chef restaurant',
#   '90012',
#   '2136873638',
#   '937 n hill st',
#   '-1',
#   '$$',
#   '446',
#   '4.0',
#   '',
#   '7'),
#  (272,
#   'kim chuy restaurant',
#   '90012',
#   '2136877215',
#   '727 n broadway',
#   '-1',
#   '$',
#   '177',
#   '3.5',
#   '',
#   '8'),
#  (273,
#   'chinatown express',
#   '90026',
#   '2139287495',
#   '1411 echo park ave',
#   '-1',
#   '$',
#   '58',
#   '4.0',
#   '',
#   '1'),
#  (274,
#   "howard's cafe",
#   '90006',
#   '2133857991',
#   '1051 s alvarado st',
#   '-1',
#   '$',
#   '56',
#   '4.0',
#   '',
#   '1'),
#  (275,
#   'regent china inn',
#   '90012',
#   '2136803333',
#   '747 n main st',
#   '-1',
#   '$',
#   '217',
#   '4.0',
#   '$$ - $$$',
#   '3'),
#  (276,
#   'ok chinese restaurant',
#   '90042',
#   '3232592414',
#   '6320 n figueroa st',
#   '-1',
#   '$',
#   '95',
#   '3.0',
#   '',
#   '3'),
#  (277,
#   'the palace',
#   '90027',
#   '3236671595',
#   '2112 hillhurst ave',
#   '-1',
#   '$$',
#   '497',
#   '4.5',
#   '$$ - $$$',
#   '9'),
#  (278,
#   "paul's kitchen",
#   '90015',
#   '2137495004',
#   '1012 s san pedro st',
#   '-1',
#   '$$',
#   '214',
#   '3.5',
#   '',
#   '3'),
#  (279,
#   'the palace seafood & dim sum',
#   '90025',
#   '3109793377',
#   '11701 wilshire blvd',
#   '-1',
#   '$$',
#   '362',
#   '3.0',
#   '$$ - $$$',
#   '5'),
#  (280,
#   'vim thai-chinese restaurant',
#   '90027',
#   '3236621017',
#   '5132 hollywood blvd',
#   '-1',
#   '$$',
#   '123',
#   '3.0',
#   '$$ - $$$',
#   '5'),
#  (281,
#   'the dragon restaurant',
#   '90006',
#   '2133878833',
#   '966 s vermont ave',
#   '-1',
#   '$$',
#   '237',
#   '4.0',
#   '',
#   '6'),
#  (282,
#   'jin jiang restaurant',
#   '90025',
#   '3104447171',
#   '11057 santa monica blvd',
#   '-1',
#   '$$',
#   '284',
#   '3.5',
#   '$$ - $$$',
#   '8'),
#  (283,
#   "yee's chinese food",
#   '90043',
#   '3232954224',
#   '4400 w slauson ave',
#   '-1',
#   '$',
#   '136',
#   '3.0',
#   '$',
#   '6'),
#  (284,
#   'rene cafe',
#   '90017',
#   '2136899898',
#   '1123 w 7th st',
#   '-1',
#   '$$',
#   '52',
#   '3.0',
#   '$',
#   '1'),
#  (285,
#   'egg roll king',
#   '90065',
#   '3232565271',
#   '3111 n san fernando rd',
#   '-1',
#   '$',
#   '28',
#   '-1',
#   '',
#   '-1'),
#  (286,
#   'cemitas la china poblana',
#   '90023',
#   '3232638310',
#   '3568 whittier blvd',
#   '-1',
#   '$',
#   '126',
#   '-1',
#   '',
#   '-1'),
#  (287,
#   'san hing',
#   '90034',
#   '3103981689',
#   '11136 palms blvd',
#   '-1',
#   '$',
#   '100',
#   '-1',
#   '',
#   '-1'),
#  (288,
#   'the griddle cafe',
#   '90046',
#   '3238740377',
#   '7916 w sunset blvd',
#   '-1',
#   '$$',
#   '4516',
#   '4.5',
#   '$$ - $$$',
#   '1131'),
#  (289,
#   'water grill',
#   '90071',
#   '2138910900',
#   '544 s grand ave',
#   '-1',
#   '$$$',
#   '1525',
#   '4.5',
#   '$$$$',
#   '536'),
#  (290,
#   'philippe the original',
#   '90012',
#   '2136283781',
#   '1001 n alameda st',
#   '-1',
#   '$',
#   '4918',
#   '4.5',
#   '$',
#   '1483'),
#  (291,
#   'craft',
#   '90067',
#   '3102794180',
#   '10100 constellation blvd',
#   '-1',
#   '$$$$',
#   '1457',
#   '4.5',
#   '$$$$',
#   '413'),
#  (292,
#   "langer's",
#   '90057',
#   '2134838050',
#   '704 s alvarado st',
#   '-1',
#   '$$',
#   '2936',
#   '4.5',
#   '$$ - $$$',
#   '352'),
#  (293,
#   'eggslut',
#   '90013',
#   '2136250292',
#   '317 s broadway',
#   '-1',
#   '$',
#   '3928',
#   '4.5',
#   '$',
#   '238'),
#  (294,
#   'the cheesecake factory',
#   '90036',
#   '3236340511',
#   '189 the grove dr',
#   '-1',
#   '$$',
#   '890',
#   '4.5',
#   '$$ - $$$',
#   '1386'),
#  (295,
#   'lemonade',
#   '90291',
#   '3104526200',
#   '1661 abbot kinney blvd',
#   '-1',
#   '$$',
#   '1247',
#   '4.5',
#   '$$ - $$$',
#   '280'),
#  (296,
#   "joan's on third",
#   '90048',
#   '3236552285',
#   '8350 w 3rd st',
#   '-1',
#   '$$',
#   '1825',
#   '4.5',
#   '$$ - $$$',
#   '400'),
#  (297,
#   'bottega louie',
#   '90017',
#   '2138021470',
#   '700 s grand ave',
#   '-1',
#   '$$',
#   '13803',
#   '4.5',
#   '$$ - $$$',
#   '1301'),
#  (298,
#   '25 degrees',
#   '90028',
#   '3237857244',
#   '7000 hollywood blvd',
#   '-1',
#   '$$',
#   '1652',
#   '4.5',
#   '$$ - $$$',
#   '530'),
#  (299,
#   'the pie hole',
#   '90013',
#   '2135370115',
#   '714 traction ave',
#   '-1',
#   '$$',
#   '2497',
#   '4.5',
#   '$$ - $$$',
#   '194'),
#  (300,
#   "canter's deli",
#   '90036',
#   '3236512030',
#   '419 n fairfax ave',
#   '-1',
#   '$$',
#   '2701',
#   '4.0',
#   '$$ - $$$',
#   '508'),
#  (301,
#   'the restaurant at the getty center',
#   '90049',
#   '3104406810',
#   '1200 getty center dr',
#   '-1',
#   '$$$',
#   '483',
#   '4.5',
#   '$$$$',
#   '470'),
#  (302,
#   'cafe at the getty center',
#   '90049',
#   '',
#   '1200 getty center dr',
#   '-1',
#   '$$',
#   '23',
#   '4.5',
#   '$$$$',
#   '470'),
#  (303,
#   'toast bakery cafe',
#   '90048',
#   '3236555018',
#   '8221 w 3rd st',
#   '-1',
#   '$$',
#   '1468',
#   '4.5',
#   '$$ - $$$',
#   '254'),
#  (304,
#   'original pantry cafe',
#   '90017',
#   '2139729279',
#   '877 s figueroa st',
#   '-1',
#   '$$',
#   '2160',
#   '4.0',
#   '$',
#   '596'),
#  (305,
#   "mel's drive in",
#   '90028',
#   '3234652111',
#   '1650 n highland ave',
#   '-1',
#   '$$',
#   '627',
#   '4.0',
#   '$$ - $$$',
#   '614'),
#  (306,
#   'yard house',
#   '90015',
#   '2137459273',
#   '800 west olympic blvd',
#   '-1',
#   '$$',
#   '1829',
#   '4.0',
#   '$$ - $$$',
#   '433'),
#  (307,
#   "roscoe's house of chicken & waffles",
#   '90028',
#   '3234667453',
#   '1514 n gower st',
#   '-1',
#   '$$',
#   '2884',
#   '4.0',
#   '$',
#   '621'),
#  (308,
#   'aroma coffee & tea',
#   '91604',
#   '8185086505',
#   '4360 tujunga ave',
#   '-1',
#   '$$',
#   '2219',
#   '4.5',
#   '$$ - $$$',
#   '205'),
#  (309,
#   'gjusta',
#   '90291',
#   '3103140320',
#   '320 sunset ave',
#   '-1',
#   '$$',
#   '615',
#   '4.5',
#   '$$ - $$$',
#   '97'),
#  (310,
#   'the counter downtown la',
#   '90017',
#   '2132287800',
#   '725 w 7th st',
#   '-1',
#   '$$',
#   '674',
#   '4.5',
#   '$$ - $$$',
#   '155'),
#  (311,
#   'redbird',
#   '90012',
#   '2137881191',
#   '114 e 2nd st',
#   '-1',
#   '$$$',
#   '676',
#   '4.5',
#   '$$$$',
#   '126'),
#  (312,
#   "truxton's american bistro",
#   '90045',
#   '3104178789',
#   '8611 truxton ave',
#   '-1',
#   '$$',
#   '918',
#   '4.0',
#   '$$ - $$$',
#   '153'),
#  (313,
#   'urth caff\xc3\xa9 - downtown',
#   '90013',
#   '2137974534',
#   '451 s hewitt st',
#   '-1',
#   '$$',
#   '4088',
#   '4.5',
#   '$$ - $$$',
#   '181'),
#  (314,
#   'nickel diner',
#   '90013',
#   '2136238301',
#   '524 s main st',
#   '-1',
#   '$$',
#   '2123',
#   '4.5',
#   '$',
#   '223'),
#  (315,
#   'rainbow bar & grill',
#   '90069',
#   '3102784232',
#   '9015 w sunset blvd',
#   '-1',
#   '$$',
#   '657',
#   '4.5',
#   '$$ - $$$',
#   '298'),
#  (316,
#   'animal',
#   '90036',
#   '3237829225',
#   '435 n fairfax ave',
#   '-1',
#   '$$$',
#   '2902',
#   '4.5',
#   '$$$$',
#   '217'),
#  (317,
#   'otium',
#   '90012',
#   '2139358500',
#   '222 s hope st',
#   '-1',
#   '$$$',
#   '752',
#   '4.0',
#   '$$$$',
#   '150'),
#  (318,
#   "cassell's hamburgers",
#   '90020',
#   '2133875502',
#   '3600 w 6th st',
#   '-1',
#   '$$',
#   '403',
#   '4.5',
#   '$$ - $$$',
#   '86'),
#  (319,
#   'veggie grill',
#   '90046',
#   '3238227575',
#   '8000 w sunset blvd',
#   '-1',
#   '$$',
#   '889',
#   '4.5',
#   '$',
#   '138'),
#  (320,
#   'alcove caf\xc3\xa9 & bakery',
#   '90027',
#   '3236440100',
#   '1929 hillhurst ave',
#   '-1',
#   '$$',
#   '3445',
#   '4.5',
#   '$$ - $$$',
#   '244'),
#  (321,
#   'wolfgang puck at hotel bel-air',
#   '90077',
#   '3104721211',
#   '701 stone canyon rd',
#   '-1',
#   '$$$$',
#   '200',
#   '4.5',
#   '$$$$',
#   '83'),
#  (322,
#   'wood ranch bbq & grill',
#   '90036',
#   '3239376800',
#   '189 the grove dr',
#   '-1',
#   '$$',
#   '742',
#   '4.0',
#   '$$ - $$$',
#   '211'),
#  (323,
#   "pann's restaurant",
#   '90045',
#   '3237763770',
#   '6710 la tijera blvd',
#   '-1',
#   '$$',
#   '835',
#   '4.0',
#   '$$ - $$$',
#   '138'),
#  (324,
#   'plan check kitchen + bar',
#   '90025',
#   '3104441411',
#   '1800 sawtelle blvd',
#   '-1',
#   '$$',
#   '2142',
#   '4.5',
#   '$$ - $$$',
#   '108'),
#  (325,
#   'daily grill',
#   '90045',
#   '3106650149',
#   '5410 w. century blvd.',
#   '-1',
#   '$$',
#   '239',
#   '4.0',
#   '$$ - $$$',
#   '281'),
#  (326,
#   'marmalade cafe - la',
#   '90036',
#   '3239540088',
#   '6333 w 3rd st, ste e17',
#   '-1',
#   '$$',
#   '1423',
#   '4.0',
#   '$$ - $$$',
#   '174'),
#  (327,
#   'superba food + bread',
#   '90291',
#   '3109075075',
#   '1900 s lincoln blvd',
#   '-1',
#   '$$',
#   '513',
#   '4.5',
#   '$$ - $$$',
#   '78'),
#  (328,
#   'industriel',
#   '90017',
#   '2134888020',
#   '609 s grand ave',
#   '-1',
#   '$$',
#   '923',
#   '4.5',
#   '$$ - $$$',
#   '117'),
#  (329,
#   'wolfgang puck at hotel bel-air',
#   '90077',
#   '3104721211',
#   '701 stone canyon rd',
#   '-1',
#   '$$$$',
#   '200',
#   '4.0',
#   '$$$$',
#   '191'),
#  (330,
#   'odys and penelope',
#   '90036',
#   '3234331057',
#   '127 s la brea',
#   '-1',
#   '$$$',
#   '306',
#   '4.5',
#   '$$ - $$$',
#   '60'),
#  (331,
#   'cafe at the getty center',
#   '90049',
#   '',
#   '1200 getty center dr',
#   '-1',
#   '$$',
#   '23',
#   '4.0',
#   '$$ - $$$',
#   '102'),
#  (332,
#   "factor's famous deli",
#   '90035',
#   '3102789175',
#   '9420 w pico blvd',
#   '-1',
#   '$$',
#   '387',
#   '4.0',
#   '$$ - $$$',
#   '153'),
#  (333,
#   'stout',
#   '90028',
#   '3234693801',
#   '1544 n cahuenga blvd',
#   '-1',
#   '$$',
#   '1557',
#   '4.5',
#   '$$ - $$$',
#   '86'),
#  (334,
#   'tiago coffee bar & kitchen',
#   '90028',
#   '3234665600',
#   '7080 hollywood blvd',
#   '-1',
#   '$$',
#   '395',
#   '4.5',
#   '$$ - $$$',
#   '95'),
#  (335,
#   'swingers diner',
#   '90048',
#   '3236535858',
#   '8020 beverly blvd',
#   '-1',
#   '$$',
#   '927',
#   '4.0',
#   '$$ - $$$',
#   '201'),
#  (336,
#   'wolfgang puck bistro',
#   '91608',
#   '8189859653',
#   '1000 universal city plz',
#   '-1',
#   '$$',
#   '247',
#   '4.0',
#   '$$ - $$$',
#   '156'),
#  (337,
#   'umami burger - hollywood',
#   '90028',
#   '3234693100',
#   '1520 n cahuenga blvd',
#   '-1',
#   '$$',
#   '1528',
#   '4.0',
#   '$$ - $$$',
#   '352'),
#  (338,
#   'wolfgang puck bar & grill',
#   '90015',
#   '2137489700',
#   '800 w olympic blvd',
#   '-1',
#   '$$',
#   '585',
#   '4.0',
#   '$$ - $$$',
#   '267'),
#  (339,
#   'faith & flower',
#   '90015',
#   '2132390642',
#   '705 w 9th st',
#   '-1',
#   '$$$',
#   '1341',
#   '4.0',
#   '$$$$',
#   '118'),
#  (340,
#   '101 coffee shop',
#   '90028',
#   '3234671175',
#   '6145 franklin ave',
#   '-1',
#   '$$',
#   '942',
#   '4.0',
#   '$$ - $$$',
#   '247'),
#  (341,
#   'home restaurant - los feliz',
#   '90027',
#   '3236690211',
#   '1760 hillhurst ave',
#   '-1',
#   '$$',
#   '1905',
#   '4.0',
#   '$$ - $$$',
#   '119'),
#  (342,
#   'milk',
#   '90036',
#   '3239396455',
#   '7290 beverly blvd',
#   '-1',
#   '$$',
#   '5248',
#   '4.5',
#   '$',
#   '124'),
#  (343,
#   "fleming's prime steakhouse & wine bar",
#   '90015',
#   '2137459911',
#   '800 w olympic blvd',
#   '-1',
#   '$$$',
#   '1183',
#   '4.0',
#   '$$$$',
#   '216'),
#  (344,
#   'little beast restaurant',
#   '90041',
#   '3233415899',
#   '1496 colorado blvd',
#   '-1',
#   '$$',
#   '732',
#   '4.5',
#   '$$ - $$$',
#   '59'),
#  (345,
#   'son of a gun',
#   '90048',
#   '3237829033',
#   '8370 w 3rd st',
#   '-1',
#   '$$$',
#   '1394',
#   '4.5',
#   '$$ - $$$',
#   '148'),
#  (346,
#   'caf\xc3\xa9 pinot',
#   '90071',
#   '2132396500',
#   '700 w 5th st',
#   '-1',
#   '$$$',
#   '455',
#   '4.5',
#   '$$$$',
#   '160'),
#  (347,
#   'stella barra pizzeria',
#   '90028',
#   '3233014001',
#   '6372 w sunset blvd',
#   '-1',
#   '$$',
#   '804',
#   '4.5',
#   '$$ - $$$',
#   '45'),
#  (348,
#   'vibrato grill jazz',
#   '90077',
#   '3104749400',
#   '2930 n beverly glen cir',
#   '-1',
#   '$$$',
#   '419',
#   '4.5',
#   '$$$$',
#   '95'),
#  (349,
#   'little jewel of new orleans',
#   '90012',
#   '2136200461',
#   '207 ord st',
#   '-1',
#   '$$',
#   '965',
#   '4.5',
#   '$$ - $$$',
#   '52'),
#  (350,
#   'blue cow kitchen & bar',
#   '90071',
#   '2136212249',
#   '350 s grand ave',
#   '-1',
#   '$$',
#   '940',
#   '4.0',
#   '$$ - $$$',
#   '107'),
#  (351,
#   'sqirl',
#   '90029',
#   '3232848147',
#   '720 n virgil ave',
#   '-1',
#   '$$',
#   '1090',
#   '4.5',
#   '$$ - $$$',
#   '59'),
#  (352,
#   'tavern',
#   '90049',
#   '3108066464',
#   '11648 san vicente blvd',
#   '-1',
#   '$$$',
#   '987',
#   '4.0',
#   '$$$$',
#   '153'),
#  (353,
#   'the larder at tavern',
#   '90049',
#   '3108066464',
#   '11648 san vicente blvd',
#   '-1',
#   '$$',
#   '118',
#   '4.0',
#   '$$$$',
#   '153'),
#  (354,
#   "bludso's bar & que",
#   '90036',
#   '3239312583',
#   '609 n la brea ave',
#   '-1',
#   '$$',
#   '1104',
#   '4.5',
#   '$$ - $$$',
#   '58'),
#  (355,
#   'the oinkster',
#   '90041',
#   '3232556465',
#   '2005 colorado blvd',
#   '-1',
#   '$$',
#   '3170',
#   '4.0',
#   '$$ - $$$',
#   '142'),
#  (356,
#   'jacks n joe',
#   '90007',
#   '2137484565',
#   '2498 s figueroa st',
#   '-1',
#   '$$',
#   '1459',
#   '4.5',
#   '$$ - $$$',
#   '70'),
#  (357,
#   "fat sal's",
#   '90028',
#   '8556824373',
#   '1300 n highland ave',
#   '-1',
#   '$$',
#   '1163',
#   '4.5',
#   '$',
#   '44'),
#  (358,
#   'figueroa philly',
#   '90037',
#   '2137489073',
#   '3850 s figueroa st',
#   '-1',
#   '$',
#   '724',
#   '4.5',
#   '$',
#   '63'),
#  (359,
#   "fiddler's bistro",
#   '90036',
#   '3239318167',
#   '6009 w 3rd st',
#   '-1',
#   '$$',
#   '290',
#   '4.5',
#   '$$ - $$$',
#   '68'),
#  (360,
#   'district',
#   '90017',
#   '2136123185',
# ...
#   '-1',
#   '$',
#   '15',
#   '-1',
#   '',
#   '-1'),
#  (877,
#   'los petates',
#   '90022',
#   '3237234099',
#   '6116 whittier blvd',
#   '-1',
#   '$',
#   '19',
#   '-1',
#   '',
#   '-1'),
#  (878,
#   "mariscos maria's restaurant",
#   '90007',
#   '3237313108',
#   '2215 s vermont ave',
#   '-1',
#   '$$',
#   '62',
#   '-1',
#   '',
#   '-1'),
#  (879,
#   'la estrella mexican food',
#   '90031',
#   '3232251148',
#   '3733 n mission rd',
#   '-1',
#   '$',
#   '91',
#   '-1',
#   '',
#   '-1'),
#  (880,
#   'california mexican grill',
#   '90064',
#   '3104730501',
#   '11106 w olympic blvd',
#   '-1',
#   '$',
#   '44',
#   '-1',
#   '',
#   '-1'),
#  (881,
#   'el gallo giro',
#   '91402',
#   '8188915533',
#   '8309 van nuys blvd',
#   '-1',
#   '$',
#   '105',
#   '-1',
#   '',
#   '-1'),
#  (882,
#   'el taquito',
#   '90032',
#   '3232231649',
#   '5053 huntington dr n',
#   '-1',
#   '$',
#   '66',
#   '-1',
#   '',
#   '-1'),
#  (883,
#   'tacos la estrella',
#   '90065',
#   '3232585256',
#   '3415 fletcher dr',
#   '-1',
#   '$',
#   '106',
#   '-1',
#   '',
#   '-1'),
#  (884,
#   "arturo's tacos",
#   '90003',
#   '3237514302',
#   '6319 avalon blvd',
#   '-1',
#   '$',
#   '12',
#   '-1',
#   '',
#   '-1'),
#  (885,
#   'el taco mexicano no 2',
#   '90011',
#   '3232331677',
#   '1300 e vernon ave',
#   '-1',
#   '$',
#   '36',
#   '-1',
#   '',
#   '-1'),
#  (886,
#   "original bill's taco house",
#   '90189',
#   '3232331587',
#   '219 e martin luther king blvd',
#   '-1',
#   '$',
#   '29',
#   '-1',
#   '',
#   '-1'),
#  (887,
#   'tacos arandas',
#   '90003',
#   '',
#   '337 e florence ave',
#   '-1',
#   '$',
#   '25',
#   '-1',
#   '',
#   '-1'),
#  (888,
#   'tacos los tomateros',
#   '90001',
#   '',
#   '7673 s alameda st',
#   '-1',
#   '$',
#   '7',
#   '-1',
#   '',
#   '-1'),
#  (889,
#   "lolita's tamales",
#   '90022',
#   '3237244222',
#   '6050 whittier blvd',
#   '-1',
#   '$',
#   '49',
#   '-1',
#   '$$$$',
#   '-1'),
#  (890,
#   'taqueria tijuana',
#   '90003',
#   '3237501719',
#   '241 w florence ave',
#   '-1',
#   '$',
#   '61',
#   '-1',
#   '',
#   '-1'),
#  (891,
#   'taqueria montes',
#   '90001',
#   '3235822358',
#   '1911 gage ave',
#   '-1',
#   '$',
#   '3',
#   '-1',
#   '',
#   '-1'),
#  (892,
#   'cilantro always fresh',
#   '90057',
#   '2137483900',
#   '1359 s main st',
#   '-1',
#   '$',
#   '52',
#   '-1',
#   '',
#   '-1'),
#  (893,
#   'la piedad mexican restaurant',
#   '91406',
#   '8187823354',
#   '15709 vanowen st',
#   '-1',
#   '$',
#   '14',
#   '-1',
#   '',
#   '-1'),
#  (894,
#   'tacos el korita',
#   '90006',
#   '',
#   'e olympic blvd and herbert ave',
#   '-1',
#   '$',
#   '34',
#   '-1',
#   '',
#   '-1'),
#  (895,
#   'la pasadita tacos',
#   '90032',
#   '',
#   '5434 huntington dr s',
#   '-1',
#   '$',
#   '8',
#   '-1',
#   '',
#   '-1'),
#  (896,
#   'la lupita',
#   '90033',
#   '3232651456',
#   '2211 e cesar e chavez ave',
#   '-1',
#   '$$',
#   '10',
#   '-1',
#   '',
#   '-1'),
#  (897,
#   'las margaritas restaurant',
#   '90023',
#   '3232686902',
#   '2914 whittier blvd',
#   '-1',
#   '$',
#   '7',
#   '-1',
#   '',
#   '-1'),
#  (898,
#   'taco-ala-carte',
#   '90035',
#   '3105538804',
#   '9800 w pico blvd',
#   '-1',
#   '$',
#   '2',
#   '-1',
#   '',
#   '-1'),
#  (899,
#   'tacos mexico',
#   '90026',
#   '2134134823',
#   '1538 glendale blvd',
#   '-1',
#   '$',
#   '68',
#   '-1',
#   '',
#   '-1'),
#  (900,
#   "lupita's restaurant",
#   '90065',
#   '3232237835',
#   '2634 idell st',
#   '-1',
#   '$',
#   '38',
#   '-1',
#   '',
#   '-1'),
#  (901,
#   'los comales cafe no 2',
#   '90005',
#   '2133834317',
#   '3329 w 8th st',
#   '-1',
#   '$',
#   '11',
#   '-1',
#   '',
#   '-1'),
#  (902,
#   'restaurant santa cecilia',
#   '90033',
#   '3239800716',
#   '1707 mariachi plz',
#   '-1',
#   '$',
#   '22',
#   '-1',
#   '$',
#   '-1'),
#  (903,
#   'rancheros tacos',
#   '91352',
#   '8185042984',
#   '8447 sunland blvd',
#   '-1',
#   '$',
#   '34',
#   '-1',
#   '',
#   '-1'),
#  (904,
#   'la barbacha',
#   '90033',
#   '3232641451',
#   '2510 e cesar chavez ave',
#   '-1',
#   '$',
#   '47',
#   '-1',
#   '',
#   '-1'),
#  (905,
#   'taqueria el tapatio',
#   '91367',
#   '8188836142',
#   '22806 victory blvd',
#   '-1',
#   '$',
#   '365',
#   '-1',
#   '',
#   '-1'),
#  (906,
#   'la reyna restaurant',
#   '90021',
#   '2136249879',
#   '2000 e 7th st',
#   '-1',
#   '$',
#   '46',
#   '-1',
#   '',
#   '-1'),
#  (907,
#   "martita's mexican restaurant",
#   '90031',
#   '3232275752',
#   '2657 pasadena ave',
#   '-1',
#   '$',
#   '16',
#   '-1',
#   '',
#   '-1'),
#  (908,
#   'tres amigos restaurant',
#   '90029',
#   '3236629202',
#   '4869 santa monica blvd',
#   '-1',
#   '$$',
#   '13',
#   '-1',
#   '',
#   '-1'),
#  (909,
#   'tacos y burritos el texano',
#   '90033',
#   '3235471831',
#   '2308 e 4th st',
#   '-1',
#   '$',
#   '9',
#   '-1',
#   '',
#   '-1'),
#  (910,
#   'el tejado',
#   '90023',
#   '3232616661',
#   '1426 s soto st',
#   '-1',
#   '$$',
#   '50',
#   '-1',
#   '',
#   '-1'),
#  (911,
#   'last call tacos',
#   '90026',
#   '3232182327',
#   '2939 1/2 w sunset blvd',
#   '-1',
#   '$',
#   '16',
#   '-1',
#   '',
#   '-1'),
#  (912,
#   'conchitas',
#   '90029',
#   '3234985360',
#   '820 n western ave',
#   '-1',
#   '$',
#   '80',
#   '-1',
#   '',
#   '-1'),
#  (913,
#   'el kiosko mexican grill',
#   '90063',
#   '3232663301',
#   '3534 e first st',
#   '-1',
#   '$$',
#   '35',
#   '-1',
#   '',
#   '-1'),
#  (914,
#   'cocina dona chona',
#   '90001',
#   '3235813036',
#   '1938 e florence ave',
#   '-1',
#   '$',
#   '17',
#   '-1',
#   '',
#   '-1'),
#  (915,
#   'rigos taco 4',
#   '90001',
#   '3235839657',
#   '1816 firestone blvd',
#   '-1',
#   '$',
#   '11',
#   '-1',
#   '',
#   '-1'),
#  (916,
#   'super pollos rostizados',
#   '90023',
#   '3232682842',
#   '3353 whittier blvd',
#   '-1',
#   '$',
#   '11',
#   '-1',
#   '',
#   '-1'),
#  (917,
#   'tacos el patio',
#   '90029',
#   '3239570461',
#   '1157 n western ave',
#   '-1',
#   '$',
#   '48',
#   '-1',
#   '',
#   '-1'),
#  (918,
#   'las brisas',
#   '90033',
#   '3232224686',
#   '1829 e cesar chavez ave',
#   '-1',
#   '$',
#   '113',
#   '-1',
#   '$',
#   '-1'),
#  (919,
#   'mayas tacos market',
#   '90026',
#   '2134840340',
#   '1600 n alvarado st',
#   '-1',
#   '$',
#   '122',
#   '-1',
#   '',
#   '-1'),
#  (920,
#   'el guanaco restaurant',
#   '90057',
#   '2134133856',
#   '2015 w 7th st',
#   '-1',
#   '$',
#   '3',
#   '-1',
#   '',
#   '-1'),
#  (921,
#   'tacos el unico',
#   '90044',
#   '3232427447',
#   '10006 s normandie ave',
#   '-1',
#   '$',
#   '11',
#   '-1',
#   '',
#   '-1'),
#  (922,
#   'el amanecer salvadoreno',
#   '90005',
#   '2133822591',
#   '3059 w 8th st',
#   '-1',
#   '$$',
#   '28',
#   '-1',
#   '',
#   '-1'),
#  (923,
#   'el burrito jr',
#   '90019',
#   '3239395649',
#   '1018 s la brea ave',
#   '-1',
#   '$',
#   '33',
#   '-1',
#   '',
#   '-1'),
#  (924,
#   "to\xc3\xb1o's tacos",
#   '90022',
#   '3232610098',
#   '4300 cesar chavez ave',
#   '-1',
#   '$',
#   '16',
#   '-1',
#   '',
#   '-1'),
#  (925,
#   'tacos chapalita',
#   '90031',
#   '',
#   '2929 1/2 n broadway',
#   '-1',
#   '$',
#   '78',
#   '-1',
#   '',
#   '-1'),
#  (926,
#   'tacos el paisa',
#   '90032',
#   '3232238206',
#   '5234 valley blvd',
#   '-1',
#   '$',
#   '56',
#   '-1',
#   '',
#   '-1'),
#  (927,
#   'taqueria el charrito',
#   '90029',
#   '3236610467',
#   '811 n virgil ave',
#   '-1',
#   '$',
#   '48',
#   '-1',
#   '',
#   '-1'),
#  (928,
#   'el atacor restaurant',
#   '90065',
#   '3233420180',
#   '3520 n figueroa st',
#   '-1',
#   '$',
#   '144',
#   '-1',
#   '',
#   '-1'),
#  (929,
#   'tio pepe',
#   '90023',
#   '3232646453',
#   '3578 e 8th st',
#   '-1',
#   '$',
#   '15',
#   '-1',
#   '$',
#   '-1'),
#  (930,
#   'worldwide tacos',
#   '90008',
#   '3232911500',
#   '2419 w martin luther king j',
#   '-1',
#   '$',
#   '118',
#   '-1',
#   '',
#   '-1'),
#  (931,
#   'cemitas poblanas don adrian',
#   '91411',
#   '8187860328',
#   '14902 victory blvd',
#   '-1',
#   '$',
#   '124',
#   '-1',
#   '',
#   '-1'),
#  (932,
#   '6138 tacos',
#   '90042',
#   '',
#   '6138 york blvd',
#   '-1',
#   '$',
#   '9',
#   '-1',
#   '',
#   '-1'),
#  (933,
#   'shojin downtown',
#   '90013',
#   '2136170305',
#   '333 s alameda st',
#   '-1',
#   '$$',
#   '1317',
#   '4.5',
#   '$$ - $$$',
#   '85'),
#  (934,
#   'picca',
#   '90035',
#   '3102770133',
#   '9575 w pico blvd',
#   '-1',
#   '$$$',
#   '1303',
#   '4.0',
#   '$$ - $$$',
#   '148'),
#  (935,
#   'shin ramen',
#   '90028',
#   '3238744692',
#   '1655 n la brea ave',
#   '-1',
#   '$$',
#   '346',
#   '4.0',
#   '$',
#   '12'),
#  (936,
#   'yojie japanese fondue',
#   '90015',
#   '2139888808',
#   '501 w olympic blvd',
#   '-1',
#   '$$',
#   '1197',
#   '4.5',
#   '$$ - $$$',
#   '14'),
#  (937,
#   'amandine patisserie cafe',
#   '90025',
#   '3109793211',
#   '12225 wilshire blvd',
#   '-1',
#   '$$',
#   '1174',
#   '4.5',
#   '$$ - $$$',
#   '30'),
#  (938,
#   'sushi house',
#   '90064',
#   '3104791507',
#   '12013 w pico blvd',
#   '-1',
#   '$$',
#   '211',
#   '4.5',
#   '',
#   '9'),
#  (939,
#   'shibumi',
#   '90014',
#   '2132657923',
#   '815 s hill st',
#   '-1',
#   '$$$',
#   '59',
#   '5.0',
#   '$$$$',
#   '4'),
#  (940,
#   'the ramen joint',
#   '90045',
#   '4242279328',
#   '6220 w 87th st',
#   '-1',
#   '$$',
#   '186',
#   '5.0',
#   '',
#   '4'),
#  (941,
#   'mikawaya',
#   '90012',
#   '2136241681',
#   '118 japanese village plaza mall',
#   '-1',
#   '$',
#   '1247',
#   '4.5',
#   '',
#   '15'),
#  (942,
#   'totoraku',
#   '90064',
#   '3108389881',
#   '10610 w pico blvd',
#   '-1',
#   '$$$$',
#   '228',
#   '4.5',
#   '$$$$',
#   '10'),
#  (943,
#   'sake house by hikari',
#   '90020',
#   '2133894000',
#   '3465 w 6th st',
#   '-1',
#   '$$',
#   '202',
#   '5.0',
#   '',
#   '5'),
#  (944,
#   'tomodachi sushi',
#   '90024',
#   '3108248805',
#   '10975 weyburn ave',
#   '-1',
#   '$$',
#   '381',
#   '4.0',
#   '$$ - $$$',
#   '12'),
#  (945,
#   'meshuga 4 sushi',
#   '90035',
#   '3102715050',
#   '8948 w pico blvd',
#   '-1',
#   '$$',
#   '97',
#   '4.5',
#   '$$ - $$$',
#   '9'),
#  (946,
#   'waba grill',
#   '90029',
#   '3236609222',
#   '1134 n. vermont ave.',
#   '-1',
#   '$',
#   '99',
#   '4.0',
#   '$',
#   '7'),
#  (947,
#   'otomisan restaurant',
#   '90033',
#   '3235261150',
#   '2506 e 1st st',
#   '-1',
#   '$$',
#   '238',
#   '5.0',
#   '$',
#   '3'),
#  (948,
#   'kawaba rice ball',
#   '90046',
#   '3232724510',
#   '7368 melrose ave',
#   '-1',
#   '$',
#   '127',
#   '5.0',
#   '$',
#   '1'),
#  (949,
#   'aki restaurant',
#   '90025',
#   '3104798406',
#   '11513 santa monica blvd',
#   '-1',
#   '$$',
#   '143',
#   '5.0',
#   '',
#   '4'),
#  (950,
#   'sake house miro',
#   '90036',
#   '3239397075',
#   '809 s la brea ave',
#   '-1',
#   '$$',
#   '344',
#   '4.5',
#   '$$$$',
#   '3'),
#  (951,
#   'tot / teishokuya of tokyo',
#   '90012',
#   '2136800344',
#   '345 e 2nd st',
#   '-1',
#   '$$',
#   '702',
#   '4.0',
#   '$$ - $$$',
#   '13'),
#  (952,
#   'new japan by sushistop',
#   '90025',
#   '3104770557',
#   '11283 santa monica blvd',
#   '-1',
#   '$',
#   '430',
#   '4.5',
#   '',
#   '12'),
#  (953,
#   'kabosu',
#   '91602',
#   '8186234425',
#   '10155 riverside dr',
#   '-1',
#   '$$',
#   '149',
#   '4.5',
#   '',
#   '4'),
#  (954,
#   'kuishimbo restaurant',
#   '90020',
#   '2133805049',
#   '3407 w 6th st',
#   '-1',
#   '$',
#   '250',
#   '4.0',
#   '$',
#   '5'),
#  (955,
#   'echigo',
#   '90025',
#   '3108209787',
#   '12217 santa monica blvd',
#   '-1',
#   '$$$',
#   '435',
#   '4.0',
#   '$$ - $$$',
#   '16'),
#  (956,
#   'mori sushi',
#   '90064',
#   '3104793939',
#   '11500 w pico blvd',
#   '-1',
#   '$$$$',
#   '279',
#   '4.0',
#   '$$$$',
#   '16'),
#  (957,
#   'en sushi',
#   '90027',
#   '3236641891',
#   '1972 hillhurst ave',
#   '-1',
#   '$$',
#   '258',
#   '4.0',
#   '$$ - $$$',
#   '9'),
#  (958,
#   'the backhouse',
#   '90064',
#   '3104816800',
#   '10915 w pico blvd',
#   '-1',
#   '$$',
#   '630',
#   '4.0',
#   '',
#   '5'),
#  (959,
#   'sasaya',
#   '90025',
#   '3104774404',
#   '11613 santa monica blvd',
#   '-1',
#   '$$',
#   '389',
#   '4.0',
#   '$$ - $$$',
#   '8'),
#  (960,
#   'nomura sushi',
#   '91403',
#   '8189813844',
#   '14622 ventura blvd',
#   '-1',
#   '$$',
#   '494',
#   '4.5',
#   '',
#   '6'),
#  (961,
#   'hana ichimonme',
#   '90013',
#   '2136263514',
#   '333 s alameda st',
#   '-1',
#   '$',
#   '355',
#   '4.5',
#   '$',
#   '2'),
#  (962,
#   'yakuza sushi',
#   '90026',
#   '3237418282',
#   '1700 silver lake blvd',
#   '-1',
#   '$$',
#   '99',
#   '4.0',
#   '',
#   '1'),
#  (963,
#   'mia sushi',
#   '90041',
#   '3232562562',
#   '4741 eagle rock blvd',
#   '-1',
#   '$$',
#   '435',
#   '4.0',
#   '',
#   '11'),
#  (964,
#   'shin-sen-gumi hakata ramen - little tokyo',
#   '90012',
#   '2136877108',
#   '132 s central ave',
#   '-1',
#   '$$',
#   '1873',
#   '3.5',
#   '$$ - $$$',
#   '9'),
#  (965,
#   'kagaya',
#   '90012',
#   '2136171016',
#   '418 e 2nd st',
#   '-1',
#   '$$$$',
#   '528',
#   '4.5',
#   '$$$$',
#   '20'),
#  (966,
#   'daichan kaiten sushi',
#   '90064',
#   '3109145028',
#   '11301 olympic blvd',
#   '-1',
#   '$$',
#   '337',
#   '3.5',
#   '$$ - $$$',
#   '8'),
#  (967,
#   'kushi shabu',
#   '90012',
#   '2136210210',
#   '123 astronaut e s onizuka st',
#   '-1',
#   '$$',
#   '426',
#   '3.5',
#   '$$ - $$$',
#   '4'),
#  (968,
#   'atch-kotch japanese restaurant',
#   '90038',
#   '3234675537',
#   '1253 vine st',
#   '-1',
#   '$$',
#   '229',
#   '3.5',
#   '',
#   '7'),
#  (969,
#   'sushi of gari - hollywood',
#   '90028',
#   '3234006300',
#   '6201 hollywood blvd',
#   '-1',
#   '$$$',
#   '34',
#   '-1',
#   '$$ - $$$',
#   '-1'),
#  (970,
#   'tsurumaru udon honpo',
#   '90013',
#   '2136250441',
#   '333 s alameda st',
#   '-1',
#   '$',
#   '349',
#   '-1',
#   '',
#   '-1'),
#  (971,
#   'bestia',
#   '90021',
#   '2135145724',
#   '2121 e 7th pl',
#   '-1',
#   '$$$',
#   '3543',
#   '4.5',
#   '$$$$',
#   '357'),
#  (972,
#   'angelini osteria',
#   '90036',
#   '3232970070',
#   '7313 beverly blvd',
#   '-1',
#   '$$$',
#   '1341',
#   '4.5',
#   '$$ - $$$',
#   '327'),
#  (973,
#   'raffaello ristorante',
#   '90731',
#   '3105140900',
#   '400 s pacific ave',
#   '-1',
#   '$$',
#   '621',
#   '4.5',
#   '$$ - $$$',
#   '151'),
#  (974,
#   'bossa nova on sunset',
#   '90046',
#   '3234367999',
#   '7181 w sunset blvd',
#   '-1',
#   '$$',
#   '2367',
#   '4.5',
#   '$$ - $$$',
#   '368'),
#  (975,
#   'maccheroni republic',
#   '90013',
#   '2133469725',
#   '332 s broadway',
#   '-1',
#   '$$',
#   '1432',
#   '4.5',
#   '$$ - $$$',
#   '103'),
#  (976,
#   'pizzeria mozza',
#   '90036',
#   '3232970101',
#   '641 n highland ave',
#   '-1',
#   '$$$',
#   '3469',
#   '4.0',
#   '$$ - $$$',
#   '527'),
#  (977,
#   'the factory kitchen',
#   '90013',
#   '2139966000',
#   '1300 factory pl',
#   '-1',
#   '$$$',
#   '799',
#   '4.5',
#   '$$$$',
#   '167'),
#  (978,
#   'ca del sole',
#   '91602',
#   '8189854669',
#   '4100 cahuenga blvd',
#   '-1',
#   '$$',
#   '553',
#   '4.5',
#   '$$ - $$$',
#   '131'),
#  (979,
#   'madeo restaurant',
#   '90048',
#   '3108590242',
#   '8897 beverly blvd',
#   '-1',
#   '$$$$',
#   '580',
#   '4.5',
#   '$$$$',
#   '255'),
#  (980,
#   'madeo',
#   '90048',
#   '3108594903',
#   '8897 beverly hills blvd',
#   '-1',
#   '',
#   '1',
#   '4.5',
#   '$$$$',
#   '255'),
#  (981,
#   'drago centro',
#   '90071',
#   '2132288998',
#   '525 s flower st',
#   '-1',
#   '$$$',
#   '1308',
#   '4.0',
#   '$$$$',
#   '211'),
#  (982,
#   'osteria mozza',
#   '90038',
#   '3232970100',
#   '6602 melrose ave',
#   '-1',
#   '$$$$',
#   '2191',
#   '4.0',
#   '$$$$',
#   '495'),
#  (983,
#   'trastevere',
#   '90028',
#   '3239623700',
#   '6801 hollywood blvd',
#   '-1',
#   '$$',
#   '222',
#   '4.0',
#   '$$ - $$$',
#   '353'),
#  (984,
#   'culina',
#   '90048',
#   '3108604000',
#   '300 s doheny dr',
#   '-1',
#   '$$$',
#   '338',
#   '4.5',
#   '$$$$',
#   '206'),
#  (985,
#   "jino's pars",
#   '90045',
#   '3106456666',
#   '5844 w manchester ave',
#   '-1',
#   '$$',
#   '303',
#   '4.5',
#   '$$ - $$$',
#   '97'),
#  (986,
#   'officine brera',
#   '90021',
#   '2135538006',
#   '1331 e 6th st',
#   '-1',
#   '$$$',
#   '210',
#   '4.5',
#   '$$$$',
#   '34'),
#  (987,
#   "maggiano's little italy",
#   '90036',
#   '3239659665',
#   '189 the grove dr',
#   '-1',
#   '$$',
#   '1226',
#   '4.0',
#   '$$ - $$$',
#   '185'),
#  (988,
#   "miceli's",
#   '90068',
#   '3238513344',
#   '3655 cahuenga blvd w',
#   '-1',
#   '$$',
#   '569',
#   '4.0',
#   '$$ - $$$',
#   '121'),
#  (989,
#   'masa of echo park',
#   '90026',
#   '2139891558',
#   '1800 w sunset blvd',
#   '-1',
#   '$$',
#   '3077',
#   '4.5',
#   '$$ - $$$',
#   '94'),
#  (990,
#   'mr. c restaurant',
#   '90035',
#   '3102266245',
#   '1224 beverwil dr',
#   '-1',
#   '$$$',
#   '135',
#   '4.5',
#   '$$$$',
#   '75'),
#  (991,
#   'sotto',
#   '90035',
#   '3102770210',
#   '9575 w pico blvd',
#   '-1',
#   '$$$',
#   '582',
#   '4.0',
#   '$$ - $$$',
#   '95'),
#  (992,
#   'terroni downtown',
#   '90015',
#   '2132217234',
#   '802 s spring st',
#   '-1',
#   '$$',
#   '589',
#   '4.0',
#   '$$ - $$$',
#   '65'),
#  (993,
#   'scopa italian roots',
#   '90292',
#   '3108211100',
#   '2905 washington blvd',
#   '-1',
#   '$$$',
#   '610',
#   '4.0',
#   '$$ - $$$',
#   '86'),
#  (994,
#   'il capriccio on vermont',
#   '90027',
#   '3236625900',
#   '1757 n vermont ave',
#   '-1',
#   '$$',
#   '737',
#   '4.5',
#   '$$ - $$$',
#   '79'),
#  (995,
#   "rao's",
#   '90038',
#   '3239627267',
#   '1006 seward st',
#   '-1',
#   '$$$',
#   '237',
#   '4.5',
#   '$$ - $$$',
#   '49'),
#  (996,
#   'toscana',
#   '90049',
#   '3108202448',
#   '11633 san vicente blvd',
#   '-1',
#   '$$$',
#   '218',
#   '4.5',
#   '$$$$',
#   '58'),
#  (997,
#   'bar toscana',
#   '90049',
#   '3108260028',
#   '11633 san vicente blvd',
#   '-1',
#   '$$$',
#   '99',
#   '4.5',
#   '$$$$',
#   '58'),
#  (998,
#   'marino restaurant',
#   '90038',
#   '3234668812',
#   '6001 melrose ave',
#   '-1',
#   '$$$',
#   '242',
#   '4.5',
#   '$$ - $$$',
#   '64'),
#  (999,
#   "dan tana's",
#   '90069',
#   '3102759444',
#   '9071 santa monica blvd',
#   '-1',
#   '$$$',
#   '574',
#   '4.0',
#   '$$$$',
#   '212'),
#  ...]

# %%
csvfile = file("E.csv", 'wb')
writer = csv.writer(csvfile)
writer.writerow(["ID", "shop name", "postal code", "phone number", "street address",  \
        "yelp price", "yelp number of reviews", \
        "advisor star", "advisor price", "advisor number of reviews"])

writer.writerows(data)
csvfile.close()
